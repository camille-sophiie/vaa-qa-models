# %% [markdown]
# ## Import libraries

# %%
# !pip3 install youtube-transcript-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: youtube-transcript-api in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from youtube-transcript-api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (3.1)

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from transformers import pipeline
import pickle
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
import sklearn
from sklearn.metrics import f1_score
from matplotlib import pyplot as plt
import scikitplot as skplt

# %% [markdown]
# ## Get captions from videos

# %%
video_list = ['kpCEeBY5TWY', 'w9M7pg5dkeg', 'aw6E-UidcYw', 't44kc6dRNY0', 'mkRIoCtRynY' ]
language_list = ['fr', 'fr', 'fr', 'fr', 'fr']
video_trans = ""

# %%
for idx, video_name in enumerate(video_list):
    srt = YouTubeTranscriptApi.get_transcript(video_name, languages=[language_list[idx]])
    for i in range(len(srt)):
        s = srt[i]['text'] + ' '
        video_trans += s

# %% [markdown]
# ## Translate captions

# %%
model_checkpoint = "Helsinki-NLP/opus-mt-fr-en"
translator = pipeline("translation", model=model_checkpoint)

# %%
video_trans_split =  video_trans.split(' ')

# %%
n_words = len(video_trans_split)
batch_size = 200
trans_text = []
n_batches = n_words//batch_size
for i in range(n_batches):
    batch_text = ' '.join(video_trans_split[i*batch_size: (i+1)*batch_size])
    trans_text.append(translator(batch_text)[0]['translation_text'])

# %%
trans_text.append(translator(' '.join(video_trans_split[(n_batches * batch_size):]))[0]['translation_text'])

# %%
trans_text
# Out:
# ['Ladies and gentlemen, the Liberal Green delegation welcomes this message and we shall come to this point every project will follow the Federal Council in broad terms. We welcome in particular the actions on the housing stock with regard to the reduction of CO2 emissions which are gratifying that the departments are doing their utmost to maintain and strengthen environmental measures, and we welcome the fact that the army is making an essential contribution to it with regard to the attempt by a minority of the Finance Committee to impose higher standards. It is obviously commendable, but we must keep it on the ground that we must do everything we can to the reasonable extent, we trust in those who are in charge of the execution to ensure that the spirit of doing the most reasonably is present is firmly applied. We call on the minority to reject the proposed weapons programme in response to the hybrid threats that are identified to extend the pipeline network and equip the senses of calculation of the ddps are essential for preparing actions in the various tasks of our army to maintain effective and modern tank sappers is vital to ensure that',
#  'the mobility in the event of a crisis involving attacks on infrastructure or natural disasters protecting our soldiers against attacks nbc is obvious in view of the possibility that destabilization groups might have of using such means in the case of minorities which plays with the volume of acquisition our position is clear these volumes are determined by the size and capabilities of the army as you know we will soon be able to debate the capabilities and we welcome it for size it will certainly have to be addressed at the same time as the overall revision of the concept of citizen service is the liberal Greens are convinced that resizing is necessary but until then it seems unreasonable to us to put pressure on the staff by reducing the masts we therefore invite to enter into the matter and to refuse the minorities wages grat and to pork to Article 2 as regards the weapons programme as regards the acquisition of the material we look at a few points with a critical eye first of all direct support to the companies to draw the inefficient system from the compulsory firings we have heard that this criticism regarding the acquisition of the equipment we do not look at a few points first from a critical point of view from the point of view of direct support to the inefficient system of compulsory fire.',
#  'We are now beginning to stand up also at the level of the centre, which is said to be constant, and we are going to be led to fight fire, which usually leaves me dubitative. We are aware that there is a legal basis for this support, but we should finally tackle this problem from the point of view of efficiency. The Green Liberals will support the same minority. Article 2 second, it is apparent from the message of critical choices regarding direct action capabilities such as heavy tanks or medium-range live action capabilities such as armoured shells in fact in the report its prospects for the development of the capabilities of the land forces the extension of the use of leopard tanks is considered as the third is less good option to consider as regards the extension of the use of the shells it does not like me considered in the said report, yet this is what is seen in the present message. We have been told that we had to do with the priorities of the available means. We find it a pity that, by habit, a lack of vision we continue to keep to the costs of obsolete systems and clearly identified as such in the reports of experts we were, will soon see things moving about these systems that are too heavy which center.',
#  "we are also aware that the capacities of direct and indirect action must be preserved and that we cannot make them disappear pending the acquisition of modern means we therefore invite you to reject the fiva minority in Article 2 you will have found that we are essentially following federal advice on this message but we are a patient to debate on the basis of the new type of messages on the army announced for the Federal Council for 2024 [Music] non- Colleagues I have a certain sympathy for this project because the traditions are close to my heart and it is a tradition that provides to pay for an image although a little old-fashioned a sympathetic image from elsewhere is registered to no one we participate in the financing of their barracks but honestly I can only adhere to the position of the Federal Council the pope's guards carry out a police service for a foreign state further restrictions of recruitment limited to men of Catholic faith without speaking of restrictions to the physical requirements of size or other strongly limit the representativeness to beetic of this body we are told that they are",
#  "a positive image of our country certainly but what to say of those who work throughout the world whose ongs or to the civil promotion of the pair also had a real impact on the foreign policy of Swiss we are told that this adoption is necessary as support for the low incomes that the Vatican certainly provides them but in what it is the responsibility of our country the report also indicates and it was one of the main objectives of this parliamentary initiative that this project should facilitate the recruitment of Swiss guards which we really need to deal with the lack of attractiveness of the Pope's map we already have enough difficulties with our own army in short you will have understood it to make an exception in this case we seem reasonable and we invite you to follow the porchet minority and not to enter into matters [Music] climate change is the human influence are not a myth it is time to act and that you will tell your children and little children if you decide not to make any energy transition and foot are above all exciting challenges.",
#  'to raise our economy is ready young people are trained for innovation and look at the future with optimism the law on co2 lays the framework a city and covers the doors to solutions it has for the aim that Swiss reduce its emissions of co2 and this obviously has a cost but the cost of inaction would be much higher an economic future words flowered meaning and respectful of the environment is possible the law on co2 or shows the way this federal advisor colleagues we all have the same objective to preserve our drinking water and have access to healthy and local food ladies and gentlemen of the agricultural milieu it is my heart of the day to ask you for some concessions so that the road taken is a real reduction of the risks region has obviously considered as justified that the confederation to respond to the call of the cantons it has welcomed the will of the Federal Council to clarify the missions of the army and to have established criteria of subsidiarity in the holidays our vote this autumn and which is worth a refuge to continue our participation or is such a refusal would be dramatic',
#  'for our customs and police services to which we withdraw is an essential source of information access to information and cooperation with our neighbours are two key to ensuring an acceptable level of security of our country we have endorsed the systematic use of the number avs of the modification of the avs with a large majority and here we are procrastination about this use I confess not to understand as this federal council ladies and gentlemen we all have the same objective to preserve our drinking water and have access to healthy and local food finally I hope that we all have this objective the current situation is nevertheless worrying the organisations responsible for the supply of road within us in our villages and our cities are rightly worried that soon not being able to deliver water without risk to health the population is worried for its drinking water its environment to a majority seems ready to demand drastic solutions in Swiss are afraid to consume imported products with a disastrous ecological impact abroad farmers are under pressure by new constraints that the consumer demands while at the same time they benefit from the tourism of purchase.',
#  'in order to save its money doors without being looking at the sustainability of its act of purchase these same farmers minimize the impact of their activities on the environment they are attacked every time a critique has been put we are all far from being mischievous in contradictions are never to admit it and the gap between city and countryside continues to widen to metals in danger our social cohesion and I do not even speak of biocides in the paintings ladies and gentlemen representatives of the agricultural circles it is my heart of the day to ask you for some concessions so that the road taken is a real reduction of the risks I invite you [Music]']

# %% [markdown]
# ## Create context vector

# %%
context_vector = ' '.join(trans_text)

# %%
with open('topics.pickle', 'rb') as handle:
    topics_to_keyword = pickle.load(handle)

# %%
d = {'video_number': [1], 'context': [context_vector]}
df = pd.DataFrame(data=d)

# %%
classes = [set() for _ in range(len(df))]

for i, context in enumerate(df["context"]):
    for topic in topics_to_keyword:
        for keyword in topics_to_keyword[topic]:
            if keyword in context:
                classes[i].add(topic)

# %%
df['topic'] = classes

# %%
df
# Out:
#    video_number                                            context  \
# 0             1  Ladies and gentlemen, the Liberal Green delega...
#
#                                                topic
# 0  {ecology, external_relations, family, health, ...

# %% [markdown]
# ## Import df questions

# %%
df_questions = pd.read_csv('./csv/pointet_questions.csv', sep=';', encoding='latin-1')

# %%
#convert to binary
df_questions["questions"] = df_questions['questions'].str[4:-2]
df_questions.loc[df_questions['smartvote_answers'] >= 3, 'binary_smarvote_answer'] = 0
df_questions.loc[df_questions['smartvote_answers'] <= 2, 'binary_smarvote_answer'] = 1

# %%
topics =  list(topics_to_keyword.keys())

# %%
videos_with_topic = defaultdict(list)

# %%
for i in range(len(df)):
    if df.iloc[i]['topic']:
        for topic in df.iloc[i]['topic']:
            videos_with_topic[topic].append(df.iloc[i]['context'])

# %%
context_videos = {}

# %%
#join context vidoes
for topic in topics:
    context_videos[topic] = ''.join(videos_with_topic[topic])

# %%
qa_model = pipeline("question-answering", model = "deepset/roberta-base-squad2")

# %%
# THIS IS ONLY VALID FOR ONE VIDEO, NEED TO CHANGE CODE for MULTIPLE VIDEOS!!!!!!!

huggingface_answers = []
for i in tqdm(range(len(df_questions))):
    question = df_questions.iloc[i]['Simplified question']
    topic = df_questions.iloc[i]['Topic']
    context = df['context'][0]        
    huggingface_answers.append(qa_model(question = question, context = context))
# Out:
# 100%|██████████| 60/60 [01:50<00:00,  1.84s/it]

# %%
df_questions["huggingface_answers"] = huggingface_answers

# %%
df_questions.to_csv("./csv//video_answers_pointet.csv")

# %%
df_questions_videos = pd.read_csv('./csv/video_answers_pointet_label.csv', sep = ';', engine='python')

# %%
df_questions_videos
# Out:
#     Column1                                          questions  \
# 0         0  tes-vous favorable à une hausse de l'âge de la...
# 1         1  'État devrait-il renforcer son soutien financi...
# 2         2  ne initiative demande l'instauration d'un cong...
# 3         3  es rentes de la caisse de pension doivent-elle...
# 4         4  outenez-vous les efforts au niveau des cantons...
# 5         5  a Confédération devrait-elle encourager davant...
# 6         6  es personnes assurées devraient-elles contribu...
# 7         7  pprouveriez-vous le principe du consentement p...
# 8         8  ne vaccination obligatoire des enfants, basée ...
# 9         9  ne initiative demande que les subsides aux ass...
# 10       10  ne initiative souhaite donner à la Confédérati...
# 11       11  État devrait-il davantage sengager pour une ...
# 12       12  ensez-vous qu'il soit juste que les écoles oct...
# 13       13  a Confédération devrait-elle accroître son sou...
# 14       14  e concept de l'école intégrative prévoit que l...
# 15       15  eriez-vous favorable à ce que le droit de vote...
# 16       16  a limitation de l'immigration a-t-elle pour vo...
# 17       17  es personnes sans-papiers devraient-elles pouv...
# 18       18  tes-vous en faveur d'un durcissement supplémen...
# 19       19  es conditions de naturalisation devraient-elle...
# 20       20  a Confédération devrait-elle soutenir davantag...
# 21       21  a consommation de cannabis devrait-elle être l...
# 22       22  es couples de même sexe devraient-ils avoir le...
# 23       23  a réglementation de la procréation médicalemen...
# 24       24  tes-vous en faveur d'un contrôle plus strict d...
# 25       25  eriez-vous favorable à ce qu'un médecin soit a...
# 26       26  elon vous, la baisse des impôts au niveau fédé...
# 27       27  tes-vous en faveur d'une nouvelle réduction de...
# 28       28  es couples mariés devraient-ils être imposés e...
# 29       29  tes-vous en faveur d'une restriction de la con...
# 30       30  es ménages privés devraient-ils pouvoir choisi...
# 31       31  tes-vous favorable à l'introduction d'un salai...
# 32       32  es entreprises suisses devraient-elles être mi...
# 33       33  eriez-vous favorable à une libéralisation comp...
# 34       34  aut-il renforcer la protection contre le licen...
# 35       35  a Confédération devrait-elle davantage souteni...
# 36       36  'expansion du réseau mobile selon la norme 5G ...
# 37       37  es plateformes de services en ligne (p. ex. hé...
# 38       38  ne initiative demande que la Suisse cesse d'ut...
# 39       39  ctuellement, une taxe CO2 est prélevée sur les...
# 40       40  a Confédération devrait-elle soutenir davantag...
# 41       41  es tronçons autoroutiers à forte fréquentation...
# 42       42  tes-vous favorable à l'introduction de péages ...
# 43       43  tes-vous favorable à un assouplissement des me...
# 44       44  e moratoire actuel sur les plantes et les anim...
# 45       45  es paiements directs devraient-ils être accord...
# 46       46  aut-il étendre les mesures de protection de la...
# 47       47  tes-vous en faveur de réglementations plus str...
# 48       48  e financement des partis ainsi que celui des c...
# 49       49  'introduction du vote électronique lors des vo...
# 50       50  tes-vous en faveur de l'abaissement de l'âge d...
# 51       51  a Suisse devrait-elle mettre fin à l'accord de...
# 52       52  aut-il renoncer au durcissement des conditions...
# 53       53  aut-il interdire l'exportation de matériel de ...
# 54       54  tes-vous favorable à l'acquisition de nouveaux...
# 55       55  elon vous, les moyens légaux permettant de rec...
# 56       56  a Suisse doit-elle entamer des négociations d'...
# 57       57  a Suisse devrait-elle conclure un accord de li...
# 58       58  ne initiative demande que les règles de respon...
# 59       59  tes-vous en faveur de la candidature de la Sui...
#
#     smartvote_answers                                Simplified question  \
# 0                   1  ''Are you in favour of raising the retirement ...
# 1                   3           ''Should the state support childcare? ''
# 2                   1        ''Are you in favour of a paternity leave?''
# 3                   1        ''Should the finance state pension funds?''
# 4                   3                  ''Are you in favor of benefits?''
# 5                   3            ''Are you in favor of public housing?''
# 6                   2          ''Should the health insurance cost more''
# 7                   2                        ''Is organ donation good?''
# 8                   2                ''Should vaccines be compulsory? ''
# 9                   4  ''Should health be proportional to your income?''
# 10                  2           ''Should health care costs be reduced?''
# 11                  2  ''Should we care about education opportunities?''
# 12                  4                ''Should schools exempts classes?''
# 13                  1            ''Should education have more funding?''
# 14                  3              ''Do you support inclusive schools?''
# 15                  1                         'Should foreigners vote?''
# 16                  4           ''Should we limit immigration from EU?''
# 17                  3  ''Should undocumented migrants receive a statu...
# 18                  3                    ''Are you in favor of asylum?''
# 19                  3  ''Should the conditions for naturaliation be i...
# 20                  2         "Should we support foreigner integration?"
# 21                  2                        "Should cannabis be legal?"
# 22                  2         "Do we believe in homosexuality equality?"
# 23                  2  ' Should the regulation of assisted reproducti...
# 24                  2  "Do you support stricter control of equal pay ...
# 25                  1                      "Should euthanasia be legal?"
# 26                  1                           "Should we lower taxes?"
# 27                  2               "Should cantons support each other?"
# 28                  1           "Do you believe in individual taxation?"
# 29                  4  "Are you in favor of restricting competition b...
# 30                  2  "Should we be a able to choose their electrici...
# 31                  4              "Are you in favor of a minimum wage?"
# 32                  3  "Should we protect Swiss companies from foreig...
# 33                  1        "Should stores choose their opening hours?"
# 34                  3  "Should the protection against dismissal of ol...
# 35                  4  "Should we support public services in rural ar...
# 36                  1                 "Should we expand our 5G network?"
# 37                  3             "Should we regulate online platforms?"
# 38                  1         "Do you want to stop using fossil fuels?''
# 39                  1                            "Should fuel be taxed?"
# 40                  1            "Should we support renewable energies?"
# 41                  4  "Should high-traffic highway sections be exten...
# 42                  2  "Do you support the introduction of road prici...
# 43                  4  "'Are you in favor of relaxing the current pro...
# 44                  1  'Should the current moratorium on genetically ...
# 45                  2  'Should direct payments only be granted to far...
# 46                  2  "Should biodiversity protection measures be ex...
# 47                  2  "Do you support stricter animal protection reg...
# 48                  2     " Should campaign financing be transparent? ''
# 49                  3                         "Do you support e-voting?"
# 50                  3                   "Should voting at 16 be allowed"
# 51                  4                  "Should Switzerland end Shengen?"
# 52                  2  'Should the Federal Council's proposed tighten...
# 53                  3                   "Should we export war material?"
# 54                  2  "Are you in favor of acquiring new fighter air...
# 55                  2                  "Should we do more DNA analysis?"
# 56                  4     "Should Switzerland enter the European Union?"
# 57                  2  "Should Switzerlad have a free trade agreement...
# 58                  4  "Should Swiss companies have human rights and ...
# 59                  1  "Should Switzerland have a seat in the UN Secu...
#
#     Unnamed: 3               Topic  \
# 0          NaN              Family
# 1          NaN              Family
# 2          NaN              Family
# 3          NaN              Family
# 4          NaN              Family
# 5          NaN              Family
# 6          NaN              Health
# 7          NaN              Health
# 8          NaN              Health
# 9          NaN              Health
# 10         NaN              Health
# 11         NaN           Education
# 12         NaN           Education
# 13         NaN           Education
# 14         NaN           Education
# 15         NaN         Immigration
# 16         NaN         Immigration
# 17         NaN         Immigration
# 18         NaN         Immigration
# 19         NaN         Immigration
# 20         NaN         Immigration
# 21         NaN             Society
# 22         NaN             Society
# 23         NaN             Society
# 24         NaN             Society
# 25         NaN             Society
# 26         NaN            Finances
# 27         NaN            Finances
# 28         NaN            Finances
# 29         NaN            Finances
# 30         NaN             Economy
# 31         NaN             Economy
# 32         NaN             Economy
# 33         NaN             Economy
# 34         NaN             Economy
# 35         NaN             Economy
# 36         NaN      Digitalisation
# 37         NaN      Digitalisation
# 38         NaN              Energy
# 39         NaN              Energy
# 40         NaN              Energy
# 41         NaN              Energy
# 42         NaN              Energy
# 43         NaN             Ecology
# 44         NaN             Ecology
# 45         NaN             Ecology
# 46         NaN             Ecology
# 47         NaN             Ecology
# 48         NaN            Politics
# 49         NaN            Politics
# 50         NaN            Politics
# 51         NaN            Security
# 52         NaN            Security
# 53         NaN            Security
# 54         NaN            Security
# 55         NaN            Security
# 56         NaN  external_relations
# 57         NaN  external_relations
# 58         NaN  external_relations
# 59         NaN  external_relations
#
#                                         Keywords  binary_smarvote_answer  \
# 0                              pension; AHV; AVS                       1
# 1                    benefit; childcare; nursery                       0
# 2                              paternity; leave                        1
# 3                       pension; life expectancy                       1
# 4                    benefits; social assistance                       0
# 5   social housing; construction; public housing                       0
# 6         health cost; health care cost; premium                       1
# 7                                organ; donation                       1
# 8                           vaccine; vaccination                       1
# 9                  insurance; premium; subsidies                       0
# 10                  cost brake; health care cost                       1
# 11   education opportunities; subsidies; courses                       1
# 12                       religion; sex education                       0
# 13               education support; reconversion                       1
# 14                learning; school; disabilities                       0
# 15            vote; resident; communal elections                       1
# 16                    bilateral; EU; immigration                       0
# 17             undocumented; residence; migrants                       0
# 18                                        asylum                       0
# 19                                naturalisation                       0
# 20                                   integration                       1
# 21                                      cannabis                       1
# 22                               homosexual; gay                       1
# 23                                 reproducation                       1
# 24                               equal; salaries                       1
# 25                           doctor; euthanasia                        1
# 26                                         taxes                       1
# 27                       financial equalisation                        1
# 28                  individual taxation; married                       1
# 29                              company taxation                       0
# 30                                   electricity                       1
# 31                                          wage                       0
# 32          FDI; investement controls; takeovers                       0
# 33                          opening hours; shops                       1
# 34                            dismissal; workers                       0
# 35                  public services; post office                       0
# 36                                            5G                       1
# 37                          Uber; Airbnb; online                       0
# 38                            fossil; 2050; fuel                       1
# 39                              C02; natural gas                       1
# 40                             renewable; energy                       1
# 41                               motorway; lanes                       0
# 42                                  road pricing                       1
# 43                  predators; lynx; wolf; bears                       0
# 44                 plants; genetically modified                        1
# 45                 ecological; farms; pesticides                       1
# 46                                  biodiversity                       1
# 47                  animal protection; livestock                       1
# 48               campaign funding; transparency;                       1
# 49                               e-voting; votes                       0
# 50                                voting age; 16                       0
# 51                      border control; schengen                       0
# 52                                 civil service                       1
# 53                         war material; weapons                       0
# 54                          aircraft; swiss army                       1
# 55                                          dann                       1
# 56                               EU negotiations                       0
# 57                                   trade; USA                        1
# 58                     human rights; environment                       0
# 59                              security council                       1
#
#                                   huggingface_answers  cami_answer
# 0   {'score': 0.37359175086021423, 'start': 5570, ...            2
# 1   {'score': 0.07512129098176956, 'start': 6856, ...            1
# 2   {'score': 0.24946582317352295, 'start': 5570, ...            2
# 3   {'score': 0.18796247243881226, 'start': 8180, ...            2
# 4   {'score': 0.17169030010700226, 'start': 5570, ...            2
# 5   {'score': 0.43310239911079407, 'start': 5570, ...            2
# 6   {'score': 0.210253044962883, 'start': 6170, 'e...            2
# 7   {'score': 0.08147784322500229, 'start': 2671, ...            1
# 8   {'score': 0.024572717025876045, 'start': 8616,...            2
# 9   {'score': 0.08890785276889801, 'start': 7816, ...            2
# 10  {'score': 0.1520196944475174, 'start': 2716, '...            2
# 11  {'score': 0.12042591720819473, 'start': 5896, ...            1
# 12  {'score': 0.03881082683801651, 'start': 5508, ...            2
# 13  {'score': 0.03152203932404518, 'start': 6856, ...            2
# 14  {'score': 0.28976309299468994, 'start': 5570, ...            2
# 15  {'score': 0.3285607397556305, 'start': 6885, '...            2
# 16  {'score': 0.09883003681898117, 'start': 2716, ...            1
# 17  {'score': 0.055587757378816605, 'start': 5171,...            2
# 18  {'score': 0.32895293831825256, 'start': 5570, ...            2
# 19  {'score': 0.07265425473451614, 'start': 5676, ...            2
# 20  {'score': 0.12956246733665466, 'start': 2716, ...            2
# 21  {'score': 0.16684816777706146, 'start': 2671, ...            1
# 22  {'score': 0.6782804131507874, 'start': 5570, '...            2
# 23  {'score': 0.22125595808029175, 'start': 2716, ...            2
# 24  {'score': 0.24020187556743622, 'start': 5570, ...            2
# 25  {'score': 0.3038462698459625, 'start': 2671, '...            2
# 26  {'score': 0.27321794629096985, 'start': 2716, ...            2
# 27  {'score': 0.23708592355251312, 'start': 2792, ...            1
# 28  {'score': 0.35266709327697754, 'start': 5570, ...            2
# 29  {'score': 0.23485738039016724, 'start': 5570, ...            2
# 30  {'score': 0.09452348202466965, 'start': 5818, ...            0
# 31  {'score': 0.5152214765548706, 'start': 5570, '...            2
# 32  {'score': 0.06692256033420563, 'start': 8180, ...            2
# 33  {'score': 0.12573179602622986, 'start': 8180, ...            2
# 34  {'score': 0.045572202652692795, 'start': 5756,...            2
# 35  {'score': 0.0881044939160347, 'start': 2716, '...            2
# 36  {'score': 0.11256193369626999, 'start': 2716, ...            2
# 37  {'score': 0.20636813342571259, 'start': 2716, ...            2
# 38  {'score': 0.1508442759513855, 'start': 5804, '...            2
# 39  {'score': 0.09026100486516953, 'start': 2716, ...            2
# 40  {'score': 0.21785086393356323, 'start': 2716, ...            2
# 41  {'score': 0.04735597223043442, 'start': 3134, ...            2
# 42  {'score': 0.19228164851665497, 'start': 5756, ...            2
# 43  {'score': 0.3598422408103943, 'start': 5570, '...            2
# 44  {'score': 0.11661330610513687, 'start': 3158, ...            2
# 45  {'score': 0.06043821945786476, 'start': 6856, ...            2
# 46  {'score': 0.11795111745595932, 'start': 5676, ...            2
# 47  {'score': 0.2213502675294876, 'start': 5756, '...            2
# 48  {'score': 0.1204105094075203, 'start': 8180, '...            2
# 49  {'score': 0.22673381865024567, 'start': 6885, ...            2
# 50  {'score': 0.06023477017879486, 'start': 6885, ...            2
# 51  {'score': 0.13884927332401276, 'start': 2716, ...            2
# 52  {'score': 0.1501319855451584, 'start': 2716, '...            2
# 53  {'score': 0.06011000648140907, 'start': 2716, ...            2
# 54  {'score': 0.29630938172340393, 'start': 5570, ...            2
# 55  {'score': 0.027850601822137833, 'start': 8616,...            2
# 56  {'score': 0.05847549811005592, 'start': 5642, ...            2
# 57  {'score': 0.11681962013244629, 'start': 3158, ...            2
# 58  {'score': 0.2323485016822815, 'start': 5676, '...            2
# 59  {'score': 0.0892895832657814, 'start': 5113, '...            2

# %% [markdown]
# ## Evaluation

# %%
sklearn.metrics.confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answer"])
# Out:
# array([[ 0,  2, 22],
#        [ 1,  4, 31],
#        [ 0,  0,  0]])

# %%
from sklearn.metrics import confusion_matrix

labels = ['0', '1', '2']
cm = confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answer"])
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix for Tweets using All tweets')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 0  2 22]
#  [ 1  4 31]
#  [ 0  0  0]]
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# not very optimistic, transcription is not great
# --> and then we translate
# add more videos, create context vectors
