# %% [markdown]
# ## Import libraries

# %%
# !pip3 install youtube-transcript-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: youtube-transcript-api in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from youtube-transcript-api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (3.1)

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from transformers import pipeline
import pickle
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
import sklearn
from sklearn.metrics import f1_score
from matplotlib import pyplot as plt
import scikitplot as skplt

# %% [markdown]
# ## Get captions from videos

# %%
video_list = ['8zQxifWGpyc', 'X33IC8eZHsw']
language_list = ['de', 'de']
video_trans = ""

# %%
for idx, video_name in enumerate(video_list):
    srt = YouTubeTranscriptApi.get_transcript(video_name, languages=[language_list[idx]])
    for i in range(len(srt)):
        s = srt[i]['text'] + ' '
        video_trans += s

# %% [markdown]
# ## Translate captions

# %%
model_checkpoint = "Helsinki-NLP/opus-mt-de-en"
translator = pipeline("translation", model=model_checkpoint)

# %%
video_trans_split =  video_trans.split(' ')

# %%
n_words = len(video_trans_split)
batch_size = 200
trans_text = []
n_batches = n_words//batch_size
for i in range(n_batches):
    batch_text = ' '.join(video_trans_split[i*batch_size: (i+1)*batch_size])
    trans_text.append(translator(batch_text)[0]['translation_text'])

# %%
trans_text.append(translator(' '.join(video_trans_split[(n_batches * batch_size):]))[0]['translation_text'])

# %%
trans_text
# Out:
# ['the name welcome to the svp offers online order can also be fully answered where you have mandat carriers and mandat carriers live place nothing current topic name and about the question answers questions was the laxe comments giga and wog connection your name is andreas rettig bp the svp Switzerland responsible communication and the foreign policy commission of the standard ecx connect where you can find interesting information with the participants that the commission of uno migrations practically diets what means that I rather reason to shout yes that is a reason to behave like simone thomalla brahms serve why there is agreement with those a commission then what it has it often long so which means fairly moderate or agree that it is very binding to us and its idol I interrupt because what is really to be harmonious in front of the switzer will then also be looking for anono migration path that would be absolutely devastating for this country you have to imagine about the dust thrown away so that it is very important to us and its idol is really important to understand how it will be necessary to protect me',
#  'also the contract documents mode you have to present your speech with it is if I just turn to you then that Hofmann word of the specifika so legalized before illegal day of the season paper again by software the question poses by the way information search and social institutions and migration authorities always allowed what with eleven the still must take over social assistance also some of the punishment of the emigrants especially people in the country the siren to do business at once the day is a single case where the Swiss company sold the spirit of the country then would be quite similar and your 20 violations of the ekg is written by the fact that they were competent two equal in the room the terms about the contract in the house in front of the classic software is called we commit ourselves like commit to tweet what there is for possibility now the package that you would be sure to be no one that the federal council must be given the permission the terms goes yes so the idea creates the micro wing or publicly where you are in the country is twelve and I would count the trajectory of the country',
#  'for me has created so that is yes and quieter that have imagined itself but certainly so and around has the then big four until one has stopped it the fdp is the only party like public is that a foul riethers [music] the quite violent consistent for tweet active beds the innovation factor agreeing a sequence because so that the population is voting astonished as if they were trying to be the causes for which will finally be said in mystery eye height to what his wishlessly wave through referendums would be capable of that right so that was supposed to be virtually up in ehrwald the person-free movement as if actually they were looking for what they had to do on over night really advertising for the 78 where one has to look at his body and he must earliest in the home country in the rule after dust or at least is safe third country that the area is now already known that one has to have illegal migration, that one must not pay attention to them and that with pure economic refugees the problem that I have created so much desire for their home country and at least',
#  'So if the Federal Council is now packing with the migrations so if we say to the video but the signers and who would still be economic migrants to the cemetery will at least offer me the development saving on the other side that gave a red card that is not in forks at the moment is the run of the double victory car still to kill them also say so soon team has the last 50 years about dusik billione development aid with the result that they can now put together and what as you clearly studied positive the herb is sigrid the now what really is so for example in the index year report be mentioned but that for example I am about to put a bus with art works rides somewhere in pompous and you have the so-called travel site pictures and since study never born that they give also art and culture and that would then be made like burkina faso starvation on the road and steady development are the meat that is moustling but then the atlantic would not be so much improved then the atlantic would be so much better than that the federal government would be able to work together',
#  'often the simplest and my the right fischer chief additive that the lie of microcredit that you can make my other he in the sewing machine on that you tell yourself about overwater head or what I very often do exactly so that you have the printing cloth force and the taxi animal died now also more do anyway project are probably a subject matter most important how to get fritz for the good certain really very low one has yes our guest game after the tsunami in sri lanka had itself happy so mask play itself possible doku for development aid abdieski control stair level billione always this country gives who for what you are finally put out of quiz checks but lots of money run over the businesses so development bank where it completely vsg of the world bank group the African development bank Asian development bank service girl bank is all about and since we have naturally spoken back that abuse takes place in front of place the really appreciated motion federrat or get the right page built up the very thin position is to be heard under the bead',
#  "that abuse from it through 2004 to the then edition one has indeed have overtaken we only should be now come seven percent predicted it is now good in and product is Swiss the watch only device remembering since Germany the watch outside of my nazi liiert is not the wrong expression if you awoke the Swiss one you have to say that and fall in love or hair related to it she would have to guess later that the call jumps out and finds again the cares before monitors you see the country being countless left the lead and that's just the analogy they are then I have to say trust the National Socialism massively dishonored we have some things that we bring little they attract nazi past neonazis are easy to ignore me and give me a weight naja but not just an arbitrary subordinate that the company is a cohabitation or a vision up to 20 Swiss coin be vigilant but the condition that we already make the team of the neighboring Switzerland and I never bring away somehow the guard and I never know how to live",
#  "Criticism they could have compensated for the content, for example, as a brother klaus quote where even more Swiss and less than comparison he brings down and that what happened there and wants to be bad and wants to be bad, because the smell doesn't fit is racism and of course nobody would feel in one that doesn't fit or has it already at csi the father is to make the race in problems in this regard so the master is the fear but finger-tips in the master's project that you have to be careful you could almost say without her being done somewhere by someone actually was renter Swiss awoke say no matter if that somehow means this credit to others I never want it identical [music]"]

# %% [markdown]
# ## Create context vector

# %%
context_vector = ' '.join(trans_text)

# %%
with open('topics.pickle', 'rb') as handle:
    topics_to_keyword = pickle.load(handle)

# %%
d = {'video_number': [1], 'context': [context_vector]}
df = pd.DataFrame(data=d)

# %%
classes = [set() for _ in range(len(df))]

for i, context in enumerate(df["context"]):
    for topic in topics_to_keyword:
        for keyword in topics_to_keyword[topic]:
            if keyword in context:
                classes[i].add(topic)

# %%
df['topic'] = classes

# %%
df
# Out:
#    video_number                                            context  \
# 0             1  the name welcome to the svp offers online orde...
#
#                                              topic
# 0  {security, digitalisation, immigration, family}

# %% [markdown]
# ## Import df questions

# %%
df_questions = pd.read_csv('./csv/glarner_questions.csv', sep=';', encoding='latin-1')

# %%
#convert to binary
df_questions["questions"] = df_questions['questions'].str[4:-2]
df_questions.loc[df_questions['smartvote_answers'] >= 3, 'binary_smarvote_answer'] = 0
df_questions.loc[df_questions['smartvote_answers'] <= 2, 'binary_smarvote_answer'] = 1

# %%
topics =  list(topics_to_keyword.keys())

# %%
videos_with_topic = defaultdict(list)

# %%
for i in range(len(df)):
    if df.iloc[i]['topic']:
        for topic in df.iloc[i]['topic']:
            videos_with_topic[topic].append(df.iloc[i]['context'])

# %%
context_videos = {}

# %%
#join context vidoes
for topic in topics:
    context_videos[topic] = ''.join(videos_with_topic[topic])

# %%
qa_model = pipeline("question-answering", model = "srcocotero/bert-large-qa")

# %%
# THIS IS ONLY VALID FOR ONE VIDEO, NEED TO CHANGE CODE for MULTIPLE VIDEOS!!!!!!!

huggingface_answers = []
for i in tqdm(range(len(df_questions))):
    question = df_questions.iloc[i]['Simplified question']
    topic = df_questions.iloc[i]['Topic']
    context = df['context'][0]        
    huggingface_answers.append(qa_model(question = question, context = context))
# Out:
# 100%|██████████| 60/60 [04:30<00:00,  4.51s/it]

# %%
df_questions["huggingface_answers"] = huggingface_answers

# %%
df_questions.to_csv("./csv//video_answers_glarner.csv")

# %%
df_questions_videos = pd.read_csv('./csv/video_answers_glarner_label.csv', sep = ';', engine='python')

# %%
df_questions_videos
# Out:
#     Column1                                          questions  \
# 0         0  tes-vous favorable à une hausse de l'âge de la...
# 1         1  'État devrait-il renforcer son soutien financi...
# 2         2  ne initiative demande l'instauration d'un cong...
# 3         3  es rentes de la caisse de pension doivent-elle...
# 4         4  outenez-vous les efforts au niveau des cantons...
# 5         5  a Confédération devrait-elle encourager davant...
# 6         6  es personnes assurées devraient-elles contribu...
# 7         7  pprouveriez-vous le principe du consentement p...
# 8         8  ne vaccination obligatoire des enfants, basée ...
# 9         9  ne initiative demande que les subsides aux ass...
# 10       10  ne initiative souhaite donner à la Confédérati...
# 11       11  État devrait-il davantage sengager pour une ...
# 12       12  ensez-vous qu'il soit juste que les écoles oct...
# 13       13  a Confédération devrait-elle accroître son sou...
# 14       14  e concept de l'école intégrative prévoit que l...
# 15       15  eriez-vous favorable à ce que le droit de vote...
# 16       16  a limitation de l'immigration a-t-elle pour vo...
# 17       17  es personnes sans-papiers devraient-elles pouv...
# 18       18  tes-vous en faveur d'un durcissement supplémen...
# 19       19  es conditions de naturalisation devraient-elle...
# 20       20  a Confédération devrait-elle soutenir davantag...
# 21       21  a consommation de cannabis devrait-elle être l...
# 22       22  es couples de même sexe devraient-ils avoir le...
# 23       23  a réglementation de la procréation médicalemen...
# 24       24  tes-vous en faveur d'un contrôle plus strict d...
# 25       25  eriez-vous favorable à ce qu'un médecin soit a...
# 26       26  elon vous, la baisse des impôts au niveau fédé...
# 27       27  tes-vous en faveur d'une nouvelle réduction de...
# 28       28  es couples mariés devraient-ils être imposés e...
# 29       29  tes-vous en faveur d'une restriction de la con...
# 30       30  es ménages privés devraient-ils pouvoir choisi...
# 31       31  tes-vous favorable à l'introduction d'un salai...
# 32       32  es entreprises suisses devraient-elles être mi...
# 33       33  eriez-vous favorable à une libéralisation comp...
# 34       34  aut-il renforcer la protection contre le licen...
# 35       35  a Confédération devrait-elle davantage souteni...
# 36       36  'expansion du réseau mobile selon la norme 5G ...
# 37       37  es plateformes de services en ligne (p. ex. hé...
# 38       38  ne initiative demande que la Suisse cesse d'ut...
# 39       39  ctuellement, une taxe CO2 est prélevée sur les...
# 40       40  a Confédération devrait-elle soutenir davantag...
# 41       41  es tronçons autoroutiers à forte fréquentation...
# 42       42  tes-vous favorable à l'introduction de péages ...
# 43       43  tes-vous favorable à un assouplissement des me...
# 44       44  e moratoire actuel sur les plantes et les anim...
# 45       45  es paiements directs devraient-ils être accord...
# 46       46  aut-il étendre les mesures de protection de la...
# 47       47  tes-vous en faveur de réglementations plus str...
# 48       48  e financement des partis ainsi que celui des c...
# 49       49  'introduction du vote électronique lors des vo...
# 50       50  tes-vous en faveur de l'abaissement de l'âge d...
# 51       51  a Suisse devrait-elle mettre fin à l'accord de...
# 52       52  aut-il renoncer au durcissement des conditions...
# 53       53  aut-il interdire l'exportation de matériel de ...
# 54       54  tes-vous favorable à l'acquisition de nouveaux...
# 55       55  elon vous, les moyens légaux permettant de rec...
# 56       56  a Suisse doit-elle entamer des négociations d'...
# 57       57  a Suisse devrait-elle conclure un accord de li...
# 58       58  ne initiative demande que les règles de respon...
# 59       59  tes-vous en faveur de la candidature de la Sui...
#
#     smartvote_answers                                Simplified question  \
# 0                   1  ''Are you in favour of raising the retirement ...
# 1                   4           ''Should the state support childcare? ''
# 2                   4        ''Are you in favour of a paternity leave?''
# 3                   4        ''Should the finance state pension funds?''
# 4                   1                  ''Are you in favor of benefits?''
# 5                   4            ''Are you in favor of public housing?''
# 6                   4          ''Should the health insurance cost more''
# 7                   1                        ''Is organ donation good?''
# 8                   4                ''Should vaccines be compulsory? ''
# 9                   4  ''Should health be proportional to your income?''
# 10                  1           ''Should health care costs be reduced?''
# 11                  1  ''Should we care about education opportunities?''
# 12                  4                ''Should schools exempts classes?''
# 13                  4            ''Should education have more funding?''
# 14                  4              ''Do you support inclusive schools?''
# 15                  4                         'Should foreigners vote?''
# 16                  1           ''Should we limit immigration from EU?''
# 17                  4  ''Should undocumented migrants receive a statu...
# 18                  1                    ''Are you in favor of asylum?''
# 19                  1  ''Should the conditions for naturaliation be i...
# 20                  4         "Should we support foreigner integration?"
# 21                  4                        "Should cannabis be legal?"
# 22                  1         "Do we believe in homosexuality equality?"
# 23                  4  ' Should the regulation of assisted reproducti...
# 24                  4  "Do you support stricter control of equal pay ...
# 25                  1                      "Should euthanasia be legal?"
# 26                  1                           "Should we lower taxes?"
# 27                  1               "Should cantons support each other?"
# 28                  4           "Do you believe in individual taxation?"
# 29                  4  "Are you in favor of restricting competition b...
# 30                  1  "Should we be a able to choose their electrici...
# 31                  4              "Are you in favor of a minimum wage?"
# 32                  2  "Should we protect Swiss companies from foreig...
# 33                  1        "Should stores choose their opening hours?"
# 34                  4  "Should the protection against dismissal of ol...
# 35                  1  "Should we support public services in rural ar...
# 36                  1                 "Should we expand our 5G network?"
# 37                  4             "Should we regulate online platforms?"
# 38                  4         "Do you want to stop using fossil fuels?''
# 39                  4                            "Should fuel be taxed?"
# 40                  4            "Should we support renewable energies?"
# 41                  1  "Should high-traffic highway sections be exten...
# 42                  4  "Do you support the introduction of road prici...
# 43                  1  "'Are you in favor of relaxing the current pro...
# 44                  4  'Should the current moratorium on genetically ...
# 45                  4  'Should direct payments only be granted to far...
# 46                  4  "Should biodiversity protection measures be ex...
# 47                  4  "Do you support stricter animal protection reg...
# 48                  4     " Should campaign financing be transparent? ''
# 49                  4                         "Do you support e-voting?"
# 50                  4                   "Should voting at 16 be allowed"
# 51                  1                  "Should Switzerland end Shengen?"
# 52                  4  'Should the Federal Council's proposed tighten...
# 53                  4                   "Should we export war material?"
# 54                  1  "Are you in favor of acquiring new fighter air...
# 55                  1                  "Should we do more DNA analysis?"
# 56                  4     "Should Switzerland enter the European Union?"
# 57                  1  "Should Switzerlad have a free trade agreement...
# 58                  4  "Should Swiss companies have human rights and ...
# 59                  4  "Should Switzerland have a seat in the UN Secu...
#
#     Unnamed: 3               Topic  \
# 0          NaN              Family
# 1          NaN              Family
# 2          NaN              Family
# 3          NaN              Family
# 4          NaN              Family
# 5          NaN              Family
# 6          NaN              Health
# 7          NaN              Health
# 8          NaN              Health
# 9          NaN              Health
# 10         NaN              Health
# 11         NaN           Education
# 12         NaN           Education
# 13         NaN           Education
# 14         NaN           Education
# 15         NaN         Immigration
# 16         NaN         Immigration
# 17         NaN         Immigration
# 18         NaN         Immigration
# 19         NaN         Immigration
# 20         NaN         Immigration
# 21         NaN             Society
# 22         NaN             Society
# 23         NaN             Society
# 24         NaN             Society
# 25         NaN             Society
# 26         NaN            Finances
# 27         NaN            Finances
# 28         NaN            Finances
# 29         NaN            Finances
# 30         NaN             Economy
# 31         NaN             Economy
# 32         NaN             Economy
# 33         NaN             Economy
# 34         NaN             Economy
# 35         NaN             Economy
# 36         NaN      Digitalisation
# 37         NaN      Digitalisation
# 38         NaN              Energy
# 39         NaN              Energy
# 40         NaN              Energy
# 41         NaN              Energy
# 42         NaN              Energy
# 43         NaN             Ecology
# 44         NaN             Ecology
# 45         NaN             Ecology
# 46         NaN             Ecology
# 47         NaN             Ecology
# 48         NaN            Politics
# 49         NaN            Politics
# 50         NaN            Politics
# 51         NaN            Security
# 52         NaN            Security
# 53         NaN            Security
# 54         NaN            Security
# 55         NaN            Security
# 56         NaN  external_relations
# 57         NaN  external_relations
# 58         NaN  external_relations
# 59         NaN  external_relations
#
#                                         Keywords  binary_smarvote_answer  \
# 0                              pension; AHV; AVS                       1
# 1                    benefit; childcare; nursery                       0
# 2                              paternity; leave                        0
# 3                       pension; life expectancy                       0
# 4                    benefits; social assistance                       1
# 5   social housing; construction; public housing                       0
# 6         health cost; health care cost; premium                       0
# 7                                organ; donation                       1
# 8                           vaccine; vaccination                       0
# 9                  insurance; premium; subsidies                       0
# 10                  cost brake; health care cost                       1
# 11   education opportunities; subsidies; courses                       1
# 12                       religion; sex education                       0
# 13               education support; reconversion                       0
# 14                learning; school; disabilities                       0
# 15            vote; resident; communal elections                       0
# 16                    bilateral; EU; immigration                       1
# 17             undocumented; residence; migrants                       0
# 18                                        asylum                       1
# 19                                naturalisation                       1
# 20                                   integration                       0
# 21                                      cannabis                       0
# 22                               homosexual; gay                       1
# 23                                 reproducation                       0
# 24                               equal; salaries                       0
# 25                           doctor; euthanasia                        1
# 26                                         taxes                       1
# 27                       financial equalisation                        1
# 28                  individual taxation; married                       0
# 29                              company taxation                       0
# 30                                   electricity                       1
# 31                                          wage                       0
# 32          FDI; investement controls; takeovers                       1
# 33                          opening hours; shops                       1
# 34                            dismissal; workers                       0
# 35                  public services; post office                       1
# 36                                            5G                       1
# 37                          Uber; Airbnb; online                       0
# 38                            fossil; 2050; fuel                       0
# 39                              C02; natural gas                       0
# 40                             renewable; energy                       0
# 41                               motorway; lanes                       1
# 42                                  road pricing                       0
# 43                  predators; lynx; wolf; bears                       1
# 44                 plants; genetically modified                        0
# 45                 ecological; farms; pesticides                       0
# 46                                  biodiversity                       0
# 47                  animal protection; livestock                       0
# 48               campaign funding; transparency;                       0
# 49                               e-voting; votes                       0
# 50                                voting age; 16                       0
# 51                      border control; schengen                       1
# 52                                 civil service                       0
# 53                         war material; weapons                       0
# 54                          aircraft; swiss army                       1
# 55                                          dann                       1
# 56                               EU negotiations                       0
# 57                                   trade; USA                        1
# 58                     human rights; environment                       0
# 59                              security council                       0
#
#                                   huggingface_answers  cami_answer
# 0   {'score': 0.009831558912992477, 'start': 4868,...            2
# 1   {'score': 0.035095810890197754, 'start': 4350,...            2
# 2   {'score': 0.0035367729142308235, 'start': 264,...            2
# 3   {'score': 0.10839856415987015, 'start': 4933, ...            2
# 4   {'score': 0.16551409661769867, 'start': 4933, ...            2
# 5   {'score': 0.009814958088099957, 'start': 6730,...            2
# 6   {'score': 0.01859523542225361, 'start': 6705, ...            2
# 7   {'score': 0.016926124691963196, 'start': 6705,...            2
# 8   {'score': 0.004641492385417223, 'start': 6720,...            2
# 9   {'score': 0.00683863228186965, 'start': 5544, ...            2
# 10  {'score': 0.0076055871322751045, 'start': 6327...            2
# 11  {'score': 0.021031716838479042, 'start': 5544,...            2
# 12  {'score': 0.011045551858842373, 'start': 6730,...            2
# 13  {'score': 0.005489315837621689, 'start': 6730,...            2
# 14  {'score': 0.008617028594017029, 'start': 6705,...            2
# 15  {'score': 0.018847815692424774, 'start': 6730,...            2
# 16  {'score': 0.04278738424181938, 'start': 6390, ...            2
# 17  {'score': 0.01677839271724224, 'start': 3130, ...            0
# 18  {'score': 0.03331685811281204, 'start': 3219, ...            2
# 19  {'score': 0.031995899975299835, 'start': 4255,...            2
# 20  {'score': 0.022579921409487724, 'start': 6705,...            2
# 21  {'score': 0.042203035205602646, 'start': 1268,...            2
# 22  {'score': 0.02142041176557541, 'start': 6705, ...            2
# 23  {'score': 0.00884857214987278, 'start': 6730, ...            2
# 24  {'score': 0.005241737700998783, 'start': 6327,...            2
# 25  {'score': 0.012016942724585533, 'start': 3146,...            2
# 26  {'score': 0.01780409924685955, 'start': 6705, ...            2
# 27  {'score': 0.00404404615983367, 'start': 5571, ...            2
# 28  {'score': 0.008425191044807434, 'start': 6545,...            2
# 29  {'score': 0.010503432713449001, 'start': 6327,...            2
# 30  {'score': 0.045154377818107605, 'start': 6346,...            2
# 31  {'score': 0.01847170665860176, 'start': 3711, ...            2
# 32  {'score': 0.08398842811584473, 'start': 6346, ...            2
# 33  {'score': 0.007777006831020117, 'start': 2917,...            2
# 34  {'score': 0.01786312647163868, 'start': 6327, ...            2
# 35  {'score': 0.03544815257191658, 'start': 6390, ...            2
# 36  {'score': 0.01848991960287094, 'start': 6346, ...            2
# 37  {'score': 0.015373480506241322, 'start': 6705,...            2
# 38  {'score': 0.008619213476777077, 'start': 6730,...            2
# 39  {'score': 0.02445279248058796, 'start': 5547, ...            2
# 40  {'score': 0.0066594635136425495, 'start': 6327...            2
# 41  {'score': 0.0058733196929097176, 'start': 6327...            2
# 42  {'score': 0.02306627482175827, 'start': 4156, ...            2
# 43  {'score': 0.007137991022318602, 'start': 6327,...            2
# 44  {'score': 0.008088757283985615, 'start': 5544,...            2
# 45  {'score': 0.032040249556303024, 'start': 5544,...            2
# 46  {'score': 0.007779860403388739, 'start': 2519,...            2
# 47  {'score': 0.011095358058810234, 'start': 4868,...            2
# 48  {'score': 0.0032689538784325123, 'start': 4479...            2
# 49  {'score': 0.030465571209788322, 'start': 2519,...            2
# 50  {'score': 0.12390945851802826, 'start': 5547, ...            2
# 51  {'score': 0.015149859711527824, 'start': 6327,...            2
# 52  {'score': 0.02502201683819294, 'start': 2045, ...            2
# 53  {'score': 0.016464924439787865, 'start': 6705,...            2
# 54  {'score': 0.00815554615110159, 'start': 6327, ...            2
# 55  {'score': 0.01595541648566723, 'start': 6346, ...            2
# 56  {'score': 0.017985714599490166, 'start': 6327,...            2
# 57  {'score': 0.014611395075917244, 'start': 6390,...            2
# 58  {'score': 0.011754035018384457, 'start': 6730,...            2
# 59  {'score': 0.03418928384780884, 'start': 2045, ...            2

# %% [markdown]
# ## Evaluation

# %%
sklearn.metrics.confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answer"])
# Out:
# array([[ 1,  0, 36],
#        [ 0,  0, 23],
#        [ 0,  0,  0]])

# %%
from sklearn.metrics import confusion_matrix

labels = ['0', '1', '2']
cm = confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answer"])
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix for Tweets using All tweets')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 1  0 36]
#  [ 0  0 23]
#  [ 0  0  0]]
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# not very optimistic, transcription is not great
# --> and then we translate
# add more videos, create context vectors
