# %% [markdown]
# to do:
# - add more levels 1-4 instead of binary
# - more keywords to enhance context vectors
# - when no clear answer, expert
# - whole point of the work is to facilitate the expert work (expensive)
# - add more sources (more video, perhaps news api? )
# - no youtube search api, express frustration in thesis
# - 4 pages to publish for conference, code on github
# --> intro, background, approach, methodology, evaluation
# Next meeting for publication November 11

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from collections import defaultdict
from transformers import pipeline
from tqdm import tqdm
import pickle
import sklearn
from sklearn.metrics import f1_score
from matplotlib import pyplot as plt
import scikitplot as skplt

# %%
#!pip install -U scikit-learn
#!pip install scikit-plot

# %% [markdown]
# ## Import clean tweets

# %%
df = pd.read_csv("./csv/df_translated_tweets_clean.csv")

# %% [markdown]
# ## Create topics to keywords

# %%
topics_to_keyword = {}
topics_to_keyword['family'] = {'pension', 'AHV', 'AVS', 'benefit', 'benefits', 'childcare', 'nursery', 'paternity', 'pension', 'life expectancy', 'social assistance', 'social housing', 'construction', 'public housing'}
topics_to_keyword['health'] = {'health', 'premium', 'organ', 'donation', 'vaccine', 'vaccination', 'insurance', 'premium', 'subsidies', 'cost brake', 'health care cost'}
topics_to_keyword['education'] = {'education', 'courses', 'subsidies', 'religion', 'sex education', 'reconversion', 'learning', 'school', 'highschool', 'apprenticeship', 'disabilities'}
topics_to_keyword['immigration'] = {'resident', 'communal elections', 'bilateral', 'EU', 'immigration', 'foreigners', 'undocumented', 'residence', 'migrants', 'asylum', 'naturalisation', 'integration'}
topics_to_keyword['finances'] = {'taxes', 'financial equalisation', 'individual taxation', 'married', 'company taxation'}
topics_to_keyword['economy'] = {'electricity', 'wage', 'FDI', 'investment controls', 'takeovers', 'opening hours', 'shops', 'dismissal', 'workers', ' public services', 'post office'}
topics_to_keyword['digitalisation'] = {'Uber', 'Airbnb', 'online'}
topics_to_keyword['energy'] = {'fossil', 'fuel', 'C02', 'gas', 'renewable', 'energy', 'motorway', 'lanes', 'road pricing'}
topics_to_keyword['ecology'] = {'predators', 'lynx', 'bears', 'wolf', 'plants', 'genetically modified', 'ecologica', 'farms', 'pesticides', 'biodiversity', 'animals', 'livestock'}
topics_to_keyword['politics'] = {'campaigns', 'transparency', 'e-voting', 'votes', 'voting age'}
topics_to_keyword['security'] = {'border control', 'civil service', 'schengen', 'shengen', 'war', 'weapons', 'army', 'aircraft', 'dna'}
topics_to_keyword['external_relations'] = {'EU', 'trade', 'USA', 'human rights', 'environment', 'security council'}
topics_to_keyword['society'] = {'cannabis', 'homosexual', 'gay', 'lesbian', 'reproduction', 'equality', 'salaries', 'doctor', 'euthanasia'}

# %%
#save it to pickle
with open('topics.pickle', 'wb') as handle:
    pickle.dump(topics_to_keyword, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#assign topics to tweets
classes = [set() for _ in range(len(df))]

for i,tweet in enumerate(df["translated_tweets"]):
    for topic in topics_to_keyword:
        for keyword in topics_to_keyword[topic]:
            if keyword in tweet:
                classes[i].add(topic)

# %%
df["topic"] = classes

# %%
df
# Out:
#       Unnamed: 0                                             tweets  likes  \
# 0              0  Alors que le Conseil fédéral annonce des défic...      5
# 1              1  Les excédents du fonds AVS pour 2020 et 2021 s...      0
# 2              2  Es ist pikant, dass ein Fakejournalist, aber e...      4
# 3              3  Les statuts permettent l’élection directe et p...      2
# 4              4  Les Suisses et Suissesses sont un peuple de lo...      5
# ...          ...                                                ...    ...
# 1605        1605  Comment le premier parti de suisse peut-il pro...      2
# 1606        1606  CH-EU:73% des entreprises craignent que résili...      0
# 1607        1607  Suisse: De 2009 à 2014, le nombre de jeunes pr...      0
# 1608        1608  Suisse-UE: Clause de sauvegarde unilatérale: P...      1
# 1609        1609  PS Suisse - réaliste garant des libertés indiv...      1
#
#                            time   politician_id                     language  \
# 0     2022-09-14 08:08:53+00:00  CarloSommaruga  ((0, 253, 'FRENCH', 'fr'),)
# 1     2022-08-26 12:28:02+00:00  CarloSommaruga  ((0, 185, 'FRENCH', 'fr'),)
# 2     2022-08-26 12:22:12+00:00  CarloSommaruga  ((0, 244, 'GERMAN', 'de'),)
# 3     2022-08-22 05:44:51+00:00  CarloSommaruga  ((0, 288, 'FRENCH', 'fr'),)
# 4     2022-08-21 06:23:55+00:00  CarloSommaruga  ((0, 104, 'FRENCH', 'fr'),)
# ...                         ...             ...                          ...
# 1605  2015-12-08 17:13:38+00:00  CarloSommaruga  ((0, 123, 'FRENCH', 'fr'),)
# 1606  2015-12-08 10:03:12+00:00  CarloSommaruga  ((0, 120, 'FRENCH', 'fr'),)
# 1607  2015-12-07 08:51:27+00:00  CarloSommaruga  ((0, 119, 'FRENCH', 'fr'),)
# 1608  2015-12-05 15:58:37+00:00  CarloSommaruga  ((0, 118, 'FRENCH', 'fr'),)
# 1609  2015-12-05 13:53:08+00:00  CarloSommaruga  ((0, 142, 'FRENCH', 'fr'),)
#
#                                       translated_tweets  \
# 0     While the Federal Council is announcing budget...
# 1     The surplus of the AVS fund for 2020 and 2021 ...
# 2     It is piqued that a fake journalist, but a rea...
# 3     The statutes allow for direct election and by ...
# 4     The Swiss are a people of tenants, and they re...
# ...                                                 ...
# 1605  How can the first Swiss party propose so much ...
# 1606  CH-EU:73% of companies fear that termination o...
# 1607  Switzerland: From 2009 to 2014, the number of ...
# 1608  Switzerland-EU: Unilateral safeguard clause: P...
# 1609  PS Switzerland - realistic guarantor of indivi...
#
#                                   topic
# 0                                    {}
# 1                              {family}
# 2                              {family}
# 3                                    {}
# 4                                    {}
# ...                                 ...
# 1605                                 {}
# 1606  {immigration, external_relations}
# 1607                                 {}
# 1608  {immigration, external_relations}
# 1609                                 {}
#
# [1610 rows x 8 columns]

# %% [markdown]
# ### how many sentences without a topic?

# %%
res = 0
for topic in df['topic']:
    if len(topic) == 0:
        res += 1

print(res)
# many sentences without topic
# Out:
# 1132

# %% [markdown]
# # Import questions and create context tweets

# %%
#import csv
df_questions = pd.read_csv('./csv/carlo_questions_keywords.csv', sep=';', encoding='latin-1')

# %%
#convert answers to binary
df_questions["question"] = df_questions['question'].str[4:-2]
df_questions.loc[df_questions['smartvote_answers'] >= 3, 'binary_smarvote_answer'] = 0
df_questions.loc[df_questions['smartvote_answers'] <= 2, 'binary_smarvote_answer'] = 1

# %%
topics = ["family", "health", "education", "immigration", "finances", "economy", "digitalisation", "energy", "ecology", "politics", "security", "external_relations", "society"]

# %%
tweets_with_topic = defaultdict(list)

# %%
for i in range(len(df)):
    if df.iloc[i]['topic']:
        for topic in df.iloc[i]['topic']:
            tweets_with_topic[topic].append(df.iloc[i]['translated_tweets'])

# %%
context_tweets = {}

# %%
#join context tweets
for topic in topics:
    context_tweets[topic] = ''.join(tweets_with_topic[topic])

# %% [markdown]
# ## QA model

# %%
qa_model = pipeline("question-answering", model = "srcocotero/bert-large-qa")
#qa_model(question = question_paternity_leave, context = context_tweets_all)

# %%
huggingface_answers = []
for i in tqdm(range(len(df_questions))):
    question = df_questions.iloc[i]['Simplified question']
    context = context_tweets[df_questions.iloc[i]['Topic'].lower()]
    huggingface_answers.append(qa_model(question = question, context = context))
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 100%|██████████| 60/60 [16:40<00:00, 16.68s/it]

# %%
df_questions["huggingface_answers"] = huggingface_answers

# %%
df_questions.to_csv("./csv/questions/df_questions_context.csv" )

#0 negative
#1 positive
#2 no answers

# %%
df_questions_context_cami=pd.read_csv("./csv/questions/df_questions_context_cami_label.csv", delimiter = ';')

# %%
df_questions_context_all_cami=pd.read_csv("./csv/questions/df_questions_context_all_cami_label.csv", delimiter = ';')

# %%
df_questions_context_cami
# Out:
#     Column1                                           question  \
# 0         0  Êtes-vous favorable à une hausse de l'âge de l...
# 1         1   L'État devrait-il renforcer son soutien finan...
# 2         2   Une initiative demande l'instauration d'un co...
# 3         3   Les rentes de la caisse de pension doivent-el...
# 4         4   Soutenez-vous les efforts au niveau des canto...
# 5         5   La Confédération devrait-elle encourager dava...
# 6         6   Les personnes assurées devraient-elles contri...
# 7         7   Approuveriez-vous le principe du consentement...
# 8         8  Une vaccination obligatoire des enfants basée ...
# 9         9   Une initiative demande que les subsides aux a...
# 10       10   Une initiative souhaite donner à la Confédéra...
# 11       11   LÉtat devrait-il davantage sengager pour un...
# 12       12   Pensez-vous qu'il soit juste que les écoles o...
# 13       13   La Confédération devrait-elle accroître son s...
# 14       14   Le concept de l'école intégrative prévoit que...
# 15       15   Seriez-vous favorable à ce que le droit de vo...
# 16       16   La limitation de l'immigration a-t-elle pour ...
# 17       17   Les personnes sans-papiers devraient-elles po...
# 18       18   Êtes-vous en faveur d'un durcissement supplém...
# 19       19   Les conditions de naturalisation devraient-el...
# 20       20   La Confédération devrait-elle soutenir davant...
# 21       21   La consommation de cannabis devrait-elle être...
# 22       22   Les couples de même sexe devraient-ils avoir ...
# 23       23  La réglementation de la procréation médicaleme...
# 24       24   Êtes-vous en faveur d'un contrôle plus strict...
# 25       25   Seriez-vous favorable à ce qu'un médecin soit...
# 26       26  Selon vous la baisse des impôts au niveau fédé...
# 27       27   Êtes-vous en faveur d'une nouvelle réduction ...
# 28       28   Les couples mariés devraient-ils être imposés...
# 29       29   Êtes-vous en faveur d'une restriction de la c...
# 30       30   Les ménages privés devraient-ils pouvoir choi...
# 31       31   Êtes-vous favorable à l'introduction d'un sal...
# 32       32   Les entreprises suisses devraient-elles être ...
# 33       33   Seriez-vous favorable à une libéralisation co...
# 34       34   Faut-il renforcer la protection contre le lic...
# 35       35  La Confédération devrait-elle davantage souten...
# 36       36   L'expansion du réseau mobile selon la norme 5...
# 37       37   Les plateformes de services en ligne (p. ex. ...
# 38       38   Une initiative demande que la Suisse cesse d'...
# 39       39  Actuellement une taxe CO2 est prélevée sur les...
# 40       40   La Confédération devrait-elle soutenir davant...
# 41       41   Les tronçons autoroutiers à forte fréquentati...
# 42       42   Êtes-vous favorable à l'introduction de péage...
# 43       43  Êtes-vous favorable à un assouplissement des m...
# 44       44   Le moratoire actuel sur les plantes et les an...
# 45       45  Les paiements directs devraient-ils être accor...
# 46       46   Faut-il étendre les mesures de protection de ...
# 47       47  Êtes-vous en faveur de réglementations plus st...
# 48       48   Le financement des partis ainsi que celui des...
# 49       49   L'introduction du vote électronique lors des ...
# 50       50   Êtes-vous en faveur de l'abaissement de l'âge...
# 51       51   La Suisse devrait-elle mettre fin à l'accord ...
# 52       52   Faut-il renoncer au durcissement des conditio...
# 53       53   Faut-il interdire l'exportation de matériel d...
# 54       54   Êtes-vous favorable à l'acquisition de nouvea...
# 55       55  Selon vous les moyens légaux permettant de rec...
# 56       56   La Suisse doit-elle entamer des négociations ...
# 57       57   La Suisse devrait-elle conclure un accord de ...
# 58       58   Une initiative demande que les règles de resp...
# 59       59   Êtes-vous en faveur de la candidature de la S...
#
#     smartvote_answers  binary_smarvote_answer  \
# 0                   4                       0
# 1                   1                       1
# 2                   1                       1
# 3                   4                       0
# 4                   4                       0
# 5                   1                       1
# 6                   4                       0
# 7                   1                       1
# 8                   1                       1
# 9                   1                       1
# 10                  4                       0
# 11                  1                       1
# 12                  4                       0
# 13                  1                       1
# 14                  2                       1
# 15                  1                       1
# 16                  4                       0
# 17                  1                       1
# 18                  4                       0
# 19                  4                       0
# 20                  1                       1
# 21                  1                       1
# 22                  1                       1
# 23                  1                       1
# 24                  1                       1
# 25                  1                       1
# 26                  4                       0
# 27                  3                       0
# 28                  1                       1
# 29                  1                       1
# 30                  4                       0
# 31                  1                       1
# 32                  2                       1
# 33                  4                       0
# 34                  1                       1
# 35                  1                       1
# 36                  3                       0
# 37                  1                       1
# 38                  1                       1
# 39                  1                       1
# 40                  1                       1
# 41                  4                       0
# 42                  4                       0
# 43                  4                       0
# 44                  1                       1
# 45                  1                       1
# 46                  1                       1
# 47                  1                       1
# 48                  1                       1
# 49                  1                       1
# 50                  3                       0
# 51                  4                       0
# 52                  1                       1
# 53                  1                       1
# 54                  4                       0
# 55                  2                       1
# 56                  4                       0
# 57                  1                       1
# 58                  1                       1
# 59                  1                       1
#
#                                   huggingface_answers  cami_answers  \
# 0   {'score': 0.12793013453483582, 'start': 3410, ...             0
# 1   {'score': 0.08400361984968185, 'start': 3653, ...             1
# 2   {'score': 0.06410077214241028, 'start': 2271, ...             1
# 3   {'score': 0.02118701860308647, 'start': 3315, ...             2
# 4   {'score': 0.03596385940909386, 'start': 1842, ...             2
# 5   {'score': 0.03899113088846207, 'start': 4433, ...             1
# 6   {'score': 0.016997814178466797, 'start': 1156,...             0
# 7   {'score': 0.09169254451990128, 'start': 6089, ...             2
# 8   {'score': 0.035589467734098434, 'start': 5883,...             2
# 9   {'score': 0.2287500500679016, 'start': 1166, '...             1
# 10  {'score': 0.1489700824022293, 'start': 5883, '...             2
# 11  {'score': 0.0015968115767464042, 'start': 865,...             2
# 12  {'score': 6.480990123236552e-06, 'start': 540,...             2
# 13  {'score': 0.017471879720687866, 'start': 540, ...             1
# 14  {'score': 1.2678929124376737e-05, 'start': 540...             2
# 15  {'score': 0.07428153604269028, 'start': 3284, ...             1
# 16  {'score': 0.0813908651471138, 'start': 20732, ...             1
# 17  {'score': 0.23495040833950043, 'start': 15047,...             2
# 18  {'score': 0.12521684169769287, 'start': 19304,...             2
# 19  {'score': 0.4348451793193817, 'start': 1164, '...             2
# 20  {'score': 0.17979130148887634, 'start': 12581,...             1
# 21  {'score': 0.27285245060920715, 'start': 1953, ...             2
# 22  {'score': 0.11909804493188858, 'start': 2156, ...             2
# 23  {'score': 0.03851780667901039, 'start': 1932, ...             2
# 24  {'score': 0.018253719434142113, 'start': 1408,...             1
# 25  {'score': 0.21306265890598297, 'start': 1953, ...             2
# 26  {'score': 0.01087903045117855, 'start': 0, 'en...             2
# 27  {'score': 2.107626642100513e-06, 'start': 58, ...             2
# 28  {'score': 3.232849485357292e-05, 'start': 0, '...             2
# 29  {'score': 1.5431111251018592e-06, 'start': 0, ...             2
# 30  {'score': 0.11038383841514587, 'start': 362, '...             2
# 31  {'score': 0.029135003685951233, 'start': 3990,...             2
# 32  {'score': 0.05744822695851326, 'start': 362, '...             2
# 33  {'score': 0.014309031888842583, 'start': 3990,...             2
# 34  {'score': 0.0431385338306427, 'start': 4542, '...             1
# 35  {'score': 0.06623702496290207, 'start': 4595, ...             1
# 36  {'score': 2.529315246135866e-08, 'start': 554,...             2
# 37  {'score': 1.9049364254897228e-06, 'start': 939...             1
# 38  {'score': 0.016227729618549347, 'start': 2560,...             2
# 39  {'score': 0.038238413631916046, 'start': 2560,...             2
# 40  {'score': 0.07334325462579727, 'start': 3271, ...             1
# 41  {'score': 0.041654009371995926, 'start': 2880,...             2
# 42  {'score': 0.0333852618932724, 'start': 645, 'e...             2
# 43  {'score': 6.803750807193865e-07, 'start': 0, '...             2
# 44  {'score': 1.3808288485961384e-06, 'start': 149...             2
# 45  {'score': 7.0325640990631655e-06, 'start': 135...             1
# 46  {'score': 9.334892638435122e-06, 'start': 182,...             2
# 47  {'score': 1.66227653153328e-06, 'start': 0, 'e...             2
# 48  {'score': 0.12646989524364471, 'start': 3983, ...             2
# 49  {'score': 0.28753626346588135, 'start': 1709, ...             1
# 50  {'score': 0.06927928328514099, 'start': 1709, ...             2
# 51  {'score': 0.054492685943841934, 'start': 7761,...             2
# 52  {'score': 0.13047555088996887, 'start': 11561,...             2
# 53  {'score': 0.14910510182380676, 'start': 2228, ...             1
# 54  {'score': 0.1080801784992218, 'start': 9396, '...             2
# 55  {'score': 0.16791921854019165, 'start': 4415, ...             1
# 56  {'score': 0.23250329494476318, 'start': 6398, ...             1
# 57  {'score': 0.12097902595996857, 'start': 13628,...             0
# 58  {'score': 0.1311933994293213, 'start': 1922, '...             2
# 59  {'score': 0.02816496416926384, 'start': 18347,...             2
#
#                  Topic                                      Keywords  \
# 0               family                             pension; AHV; AVS
# 1               family                   benefit; childcare; nursery
# 2               family                             paternity; leave
# 3               family                      pension; life expectancy
# 4               family                   benefits; social assistance
# 5               family  social housing; construction; public housing
# 6               health        health cost; health care cost; premium
# 7               health                               organ; donation
# 8               health                          vaccine; vaccination
# 9               health                 insurance; premium; subsidies
# 10              health                  cost brake; health care cost
# 11           education   education opportunities; subsidies; courses
# 12           education                       religion; sex education
# 13           education               education support; reconversion
# 14           education                learning; school; disabilities
# 15         immigration            vote; resident; communal elections
# 16         immigration                    bilateral; EU; immigration
# 17         immigration             undocumented; residence; migrants
# 18         immigration                                        asylum
# 19         immigration                                naturalisation
# 20         immigration                                   integration
# 21             society                                      cannabis
# 22             society                               homosexual; gay
# 23             society                                 reproducation
# 24             society                               equal; salaries
# 25             society                           doctor; euthanasia
# 26            finances                                         taxes
# 27            finances                       financial equalisation
# 28            finances                  individual taxation; married
# 29            finances                              company taxation
# 30             economy                                   electricity
# 31             economy                                          wage
# 32             economy          FDI; investement controls; takeovers
# 33             economy                          opening hours; shops
# 34             economy                            dismissal; workers
# 35             economy                  public services; post office
# 36      digitalisation                                            5G
# 37      digitalisation                          Uber; Airbnb; online
# 38              energy                            fossil; 2050; fuel
# 39              energy                              C02; natural gas
# 40              energy                             renewable; energy
# 41              energy                               motorway; lanes
# 42              energy                                  road pricing
# 43             ecology                  predators; lynx; wolf; bears
# 44             ecology                 plants; genetically modified
# 45             ecology                 ecological; farms; pesticides
# 46             ecology                                  biodiversity
# 47             ecology                  animal protection; livestock
# 48            politics               campaign funding; transparency;
# 49            politics                               e-voting; votes
# 50            politics                                voting age; 16
# 51            security                      border control; schengen
# 52            security                                 civil service
# 53            security                         war material; weapons
# 54            security                          aircraft; swiss army
# 55            security                                          dann
# 56  external_relations                               EU negotiations
# 57  external_relations                                   trade; USA
# 58  external_relations                     human rights; environment
# 59  external_relations                              security council
#
#                                   Simplified question
# 0   ''Are you in favour of raising the retirement ...
# 1            ''Should the state support childcare? ''
# 2         ''Are you in favour of a paternity leave?''
# 3         ''Should the finance state pension funds?''
# 4                   ''Are you in favor of benefits?''
# 5             ''Are you in favor of public housing?''
# 6           ''Should the health insurance cost more''
# 7                         ''Is organ donation good?''
# 8                 ''Should vaccines be compulsory? ''
# 9   ''Should health be proportional to your income?''
# 10           ''Should health care costs be reduced?''
# 11  ''Should we care about education opportunities?''
# 12                ''Should schools exempts classes?''
# 13            ''Should education have more funding?''
# 14              ''Do you support inclusive schools?''
# 15                         'Should foreigners vote?''
# 16           ''Should we limit immigration from EU?''
# 17  ''Should undocumented migrants receive a statu...
# 18                    ''Are you in favor of asylum?''
# 19  ''Should the conditions for naturaliation be i...
# 20         "Should we support foreigner integration?"
# 21                        "Should cannabis be legal?"
# 22         "Do we believe in homosexuality equality?"
# 23  ' Should the regulation of assisted reproducti...
# 24  "Do you support stricter control of equal pay ...
# 25                      "Should euthanasia be legal?"
# 26                           "Should we lower taxes?"
# 27               "Should cantons support each other?"
# 28           "Do you believe in individual taxation?"
# 29  "Are you in favor of restricting competition b...
# 30  "Should we be a able to choose their electrici...
# 31              "Are you in favor of a minimum wage?"
# 32  "Should we protect Swiss companies from foreig...
# 33        "Should stores choose their opening hours?"
# 34  "Should the protection against dismissal of ol...
# 35  "Should we support public services in rural ar...
# 36                 "Should we expand our 5G network?"
# 37             "Should we regulate online platforms?"
# 38         "Do you want to stop using fossil fuels?''
# 39                            "Should fuel be taxed?"
# 40            "Should we support renewable energies?"
# 41  "Should high-traffic highway sections be exten...
# 42  "Do you support the introduction of road prici...
# 43  "'Are you in favor of relaxing the current pro...
# 44  'Should the current moratorium on genetically ...
# 45  'Should direct payments only be granted to far...
# 46  "Should biodiversity protection measures be ex...
# 47  "Do you support stricter animal protection reg...
# 48     " Should campaign financing be transparent? ''
# 49                         "Do you support e-voting?"
# 50                   "Should voting at 16 be allowed"
# 51                  "Should Switzerland end Shengen?"
# 52  'Should the Federal Council's proposed tighten...
# 53               "Should we ban export war material?"
# 54  "Are you in favor of acquiring new fighter air...
# 55                  "Should we do more DNA analysis?"
# 56     "Should Switzerland enter the European Union?"
# 57  "Should Switzerlad have a free trade agreement...
# 58  "Should Swiss companies have human rights and ...
# 59  "Should Switzerland have a seat in the UN Secu...

# %% [markdown]
# # Evaluation individual context Tweets

# %%
#might not make sense
sklearn.metrics.f1_score(df_questions_context_cami["binary_smarvote_answer"], df_questions_context_cami["cami_answers"], average=None)
# Out:
# array([0.16666667, 0.56140351, 0.        ])

# %%
sklearn.metrics.confusion_matrix(df_questions_context_cami["binary_smarvote_answer"], df_questions_context_cami["cami_answers"])
# Out:
# array([[ 2,  2, 17],
#        [ 1, 16, 22],
#        [ 0,  0,  0]])

# %%
from sklearn.metrics import confusion_matrix

labels = ['0', '1', 2]
cm = confusion_matrix(df_questions_context_cami["binary_smarvote_answer"], df_questions_context_cami["cami_answers"])
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix for tweets using context tweets')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 2  2 17]
#  [ 1 16 22]
#  [ 0  0  0]]
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# high number of unclassified, 39 as seen in the confusion matrix
#show an example from the df
#challenge: how to increase? he might not have tweeted

#otherwise for the classified, good performance
#what he says is what he thinks

# %% [markdown]
# ### what is an unclassified tweet?

# %%
df_questions_context_cami.iloc[46]["Simplified question"]
# Out:
# '"Should biodiversity protection measures be extended?"'

# %%
df_questions_context_cami.iloc[46]["huggingface_answers"]
# Out:
# "{'score': 9.334892638435122e-06, 'start': 182, 'end': 251, 'answer': 'It is now necessary to include in the law a protection of the tenants'}"

# %%
df_questions_context_cami.iloc[39]["Simplified question"]
# Out:
# '"Should fuel be taxed?"'

# %%
df_questions_context_cami.iloc[39]["huggingface_answers"]
# Out:
# "{'score': 0.038238413631916046, 'start': 2560, 'end': 2598, 'answer': 'nuclear weapons have never been banned'}"

# %% [markdown]
# # Evaluation tweets all context

# %%
#super slow

# %%
#sklearn.metrics.f1_score(df_questions_context_all_cami["binary_smarvote_answer"], df_questions_context_all_cami["cami_answers"], average=None)

# %%
sklearn.metrics.confusion_matrix(df_questions_context_all_cami["binary_smarvote_answer"], df_questions_context_all_cami["cami_answers"])
# Out:
# array([[ 2,  4, 15],
#        [ 2,  6, 31],
#        [ 0,  0,  0]])

# %%
#46 unclassified, higher than individual context vector
# according to this model, carlo is not truthful

# %%
from sklearn.metrics import confusion_matrix

labels = ['0', '1', '2']
cm = confusion_matrix(df_questions_context_all_cami["binary_smarvote_answer"], df_questions_context_all_cami["cami_answers"])
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix for Tweets using All tweets')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 2  4 15]
#  [ 2  6 31]
#  [ 0  0  0]]
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# # Questions

# %% [markdown]
# 1. what if carlo hasn't tweeted about a question? Then the model can't generate answers
# 2. suggestion to improve non-classified answers?
# 3. suggestion: add more keywords_to_tweets for more text in context (not sure)
