# %% [markdown]
# ## Import libraries

# %%
# !pip3 install youtube-transcript-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.5.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from youtube-transcript-api) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests->youtube-transcript-api) (3.1)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.5.0

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from transformers import pipeline
import pickle
import pandas as pd
from collections import defaultdict
from tqdm import tqdm
import sklearn
from sklearn.metrics import f1_score
from matplotlib import pyplot as plt
import scikitplot as skplt

# %% [markdown]
# ## Get captions from one video

# %%
srt = YouTubeTranscriptApi.get_transcript("fyXmnsX1Rr4", languages=['fr'])

# %%
srt
# Out:
# [{'text': '[Musique]', 'start': 1.87, 'duration': 4.52},
#  {'text': "votre invité aujourd'hui béatrice rule",
#   'start': 3.92,
#   'duration': 5.25},
#  {'text': "carlo sommaruga président de l'asloca",
#   'start': 6.39,
#   'duration': 5.16},
#  {'text': 'bonjour carlo sommaruga avant de vous',
#   'start': 9.17,
#   'duration': 3.58},
#  {'text': 'entendre spécifiquement sur la situation',
#   'start': 11.55,
#   'duration': 3.629},
#  {'text': "des locateurs on a pris l'habitude ce",
#   'start': 12.75,
#   'duration': 4.109},
#  {'text': 'radio lac aussi de prendre un petit peu',
#   'start': 15.179,
#   'duration': 3.241},
#  {'text': 'le pouls de nos invités comment est ce',
#   'start': 16.859,
#   'duration': 3.241},
#  {'text': "qu'ils vivent ce confinement on le sait",
#   'start': 18.42,
#   'duration': 4.08},
#  {'text': 'vous est également conseillé aux états',
#   'start': 20.1,
#   'duration': 3.39},
#  {'text': 'vous êtes habitué à vous rendre', 'start': 22.5, 'duration': 2.369},
#  {'text': "régulièrement à berne est ce que c'est",
#   'start': 23.49,
#   'duration': 3.449},
#  {'text': 'pas déjà un peu compliqué de rester le',
#   'start': 24.869,
#   'duration': 4.58},
#  {'text': 'plus possible ses choix actuellement',
#   'start': 26.939,
#   'duration': 4.951},
#  {'text': "pour écouter il est vrai qu'on a été",
#   'start': 29.449,
#   'duration': 4.901},
#  {'text': 'surpris avec la suspension des travaux',
#   'start': 31.89,
#   'duration': 4.259},
#  {'text': 'parlementaires lors de la dernière',
#   'start': 34.35,
#   'duration': 4.35},
#  {'text': 'session et le fait que la troisième',
#   'start': 36.149,
#   'duration': 4.891},
#  {'text': "semaine n'avait pas eu lieu depuis lors",
#   'start': 38.7,
#   'duration': 4.62},
#  {'text': 'on nous avons des contacts en', 'start': 41.04, 'duration': 4.109},
#  {'text': 'vidéoconférence avec nos collègues',
#   'start': 43.32,
#   'duration': 4.2},
#  {'text': 'différents partis et avec notre propre',
#   'start': 45.149,
#   'duration': 6.09},
#  {'text': 'parti les bureaux des chambres décidé',
#   'start': 47.52,
#   'duration': 6.0},
#  {'text': 'que la session aurait lieu médiation',
#   'start': 51.239,
#   'duration': 4.561},
#  {'text': 'spéciale dédiée question croit les',
#   'start': 53.52,
#   'duration': 4.41},
#  {'text': "russes au début du mois n'est donc vous",
#   'start': 55.8,
#   'duration': 4.739},
#  {'text': 'préparons maintenant cette session qui',
#   'start': 57.93,
#   'duration': 3.99},
#  {'text': 'doit aborder à différentes questions',
#   'start': 60.539,
#   'duration': 3.781},
#  {'text': "financières et probablement d'autres",
#   'start': 61.92,
#   'duration': 5.64},
#  {'text': 'volets de la politique nationale de',
#   'start': 64.32,
#   'duration': 5.6},
#  {'text': 'prévention et de lutte contre le virus',
#   'start': 67.56,
#   'duration': 4.11},
#  {'text': "d'un mot tout de même aider la", 'start': 69.92, 'duration': 3.73},
#  {'text': 'population de rester confinés puis va y',
#   'start': 71.67,
#   'duration': 4.41},
#  {'text': 'avoir plus de 200 parlementaires qui',
#   'start': 73.65,
#   'duration': 4.62},
#  {'text': "vont être ensemble c'est pas un peu",
#   'start': 76.08,
#   'duration': 4.829},
#  {'text': 'contradictoire tout de même nom comme ce',
#   'start': 78.27,
#   'duration': 4.44},
#  {'text': "n'est pas contradictoire que le conseil",
#   'start': 80.909,
#   'duration': 4.171},
#  {'text': 'fédéral continue à se réunir que les',
#   'start': 82.71,
#   'duration': 3.74},
#  {'text': "hauts fonctionnaires de l'autre pays",
#   'start': 85.08,
#   'duration': 4.23},
#  {'text': 'soit présent pour pouvoir préparer les',
#   'start': 86.45,
#   'duration': 4.3},
#  {'text': 'dossiers et faire en sorte que le pays',
#   'start': 89.31,
#   'duration': 3.69},
#  {'text': 'soit gouverné le parlement suisse un',
#   'start': 90.75,
#   'duration': 4.95},
#  {'text': "rôle essentiel c'est celui de vérifier",
#   'start': 93.0,
#   'duration': 5.79},
#  {'text': 'le travail est surveillé de travail du',
#   'start': 95.7,
#   'duration': 5.07},
#  {'text': "conseil fédéral et de l'administration",
#   'start': 98.79,
#   'duration': 4.59},
#  {'text': 'et donc il nous appartient également de',
#   'start': 100.77,
#   'duration': 5.55},
#  {'text': "valider différentes décisions c'était",
#   'start': 103.38,
#   'duration': 4.62},
#  {'text': "décisions financières puisqu'il ya",
#   'start': 106.32,
#   'duration': 4.35},
#  {'text': "beaucoup d'argent qui a été lire sur la",
#   'start': 108.0,
#   'duration': 5.46},
#  {'text': 'table et il y a également la', 'start': 110.67, 'duration': 4.769},
#  {'text': 'problématique de la mobilisation de',
#   'start': 113.46,
#   'duration': 4.65},
#  {'text': "l'armée doit selon la constitution être",
#   'start': 115.439,
#   'duration': 4.86},
#  {'text': 'validé par le parlement sinon il faut',
#   'start': 118.11,
#   'duration': 5.7},
#  {'text': "que la mesure soit il n'est pas possible",
#   'start': 120.299,
#   'duration': 6.651},
#  {'text': "aujourd'hui le contexte sanitaire",
#   'start': 123.81,
#   'duration': 5.6},
#  {'text': 'venons en à la situation des locataires',
#   'start': 126.95,
#   'duration': 4.96},
#  {'text': 'nombreux sont ceux qui sont au chômage',
#   'start': 129.41,
#   'duration': 3.7},
#  {'text': 'technique', 'start': 131.91, 'duration': 2.58},
#  {'text': 'qui se retrouve donc avec des', 'start': 133.11, 'duration': 3.15},
#  {'text': 'difficultés pour payer leur loyer le',
#   'start': 134.49,
#   'duration': 3.48},
#  {'text': 'conseil fédéral a annoncé vendredi',
#   'start': 136.26,
#   'duration': 4.17},
#  {'text': "l'extension du délai de paiement de 30 à",
#   'start': 137.97,
#   'duration': 3.12},
#  {'text': '90 jours', 'start': 140.43, 'duration': 2.4},
#  {'text': "ça c'est une vraie bouffée d'oxygène",
#   'start': 141.09,
#   'duration': 5.43},
#  {'text': "pour tous non je pense que c'est plutôt",
#   'start': 142.83,
#   'duration': 6.72},
#  {'text': 'une mesure cosmétique dans la mesure où',
#   'start': 146.52,
#   'duration': 5.76},
#  {'text': "s'il est vrai que les locataires d'un",
#   'start': 149.55,
#   'duration': 5.64},
#  {'text': "logement d'ailleurs comme de surfaces",
#   'start': 152.28,
#   'duration': 5.04},
#  {'text': 'commerciales ont des difficultés puisque',
#   'start': 155.19,
#   'duration': 3.75},
#  {'text': 'soit le revenu', 'start': 157.32, 'duration': 5.48},
#  {'text': 'le salarié à battre soit le revenu',
#   'start': 158.94,
#   'duration': 7.53},
#  {'text': "d'indépendants on n'est plus là il est",
#   'start': 162.8,
#   'duration': 5.77},
#  {'text': "clair que ce n'est pas en donnant you",
#   'start': 166.47,
#   'duration': 4.29},
#  {'text': "sad et rentre en trois mois que l'on va",
#   'start': 168.57,
#   'duration': 4.86},
#  {'text': 'pouvoir se refaire une santé financière',
#   'start': 170.76,
#   'duration': 5.31},
#  {'text': 'et ensuite pouvoir payer les retards de',
#   'start': 173.43,
#   'duration': 4.23},
#  {'text': "loyer parce que si l'on ne respecte pas",
#   'start': 176.07,
#   'duration': 4.47},
#  {'text': 'ces 90 jours pour payer le loyer cours',
#   'start': 177.66,
#   'duration': 4.38},
#  {'text': 'ont plus le retard de loyer', 'start': 180.54, 'duration': 4.919},
#  {'text': 'on risque le congé or nous le demandions',
#   'start': 182.04,
#   'duration': 5.16},
#  {'text': 'à des mesures beaucoup plus importantes',
#   'start': 185.459,
#   'duration': 3.631},
#  {'text': 'à savoir la suspension de la possibilité',
#   'start': 187.2,
#   'duration': 5.13},
#  {'text': 'de donner le congé sur des retards de',
#   'start': 189.09,
#   'duration': 6.54},
#  {'text': 'loyer commercial ou de logement il',
#   'start': 192.33,
#   'duration': 4.92},
#  {'text': 'adulte est de la crise colora de pouce',
#   'start': 195.63,
#   'duration': 4.05},
#  {'text': 'on est encore loin de cette situation là',
#   'start': 197.25,
#   'duration': 3.69},
#  {'text': 'il faudra bien que le conseil fédéral',
#   'start': 199.68,
#   'duration': 3.66},
#  {'text': 'aborde le problème de manière plus',
#   'start': 200.94,
#   'duration': 3.9},
#  {'text': "sérieuse qu'elle n'avait jusqu'à",
#   'start': 203.34,
#   'duration': 3.78},
#  {'text': 'maintenant vous vous proposé la création',
#   'start': 204.84,
#   'duration': 4.649},
#  {'text': "d'un fonds pour payer le loyer des",
#   'start': 207.12,
#   'duration': 3.36},
#  {'text': 'locataires comment est-ce que ça',
#   'start': 209.489,
#   'duration': 3.871},
#  {'text': 'fonctionnerait très concrètement nous',
#   'start': 210.48,
#   'duration': 5.069},
#  {'text': "demandons tout d'abord qu' il y ait la",
#   'start': 213.36,
#   'duration': 5.28},
#  {'text': 'gratuité des loyers pour tous les',
#   'start': 215.549,
#   'duration': 6.031},
#  {'text': 'commerçants qui ont dû fermer les locaux',
#   'start': 218.64,
#   'duration': 5.43},
#  {'text': 'en raison des décisions du conseil',
#   'start': 221.58,
#   'duration': 5.73},
#  {'text': "fédéral ou du canton il n'est pas",
#   'start': 224.07,
#   'duration': 6.12},
#  {'text': 'imaginable que des commerçants doivent',
#   'start': 227.31,
#   'duration': 4.98},
#  {'text': 'assumer le paiement du loyer ou que la',
#   'start': 230.19,
#   'duration': 4.41},
#  {'text': 'confédération voit le canton sinon ce',
#   'start': 232.29,
#   'duration': 5.55},
#  {'text': 'paiement du loyer pour le bien de',
#   'start': 234.6,
#   'duration': 6.24},
#  {'text': 'propriétaires qui percevrait les loyers',
#   'start': 237.84,
#   'duration': 4.35},
#  {'text': "comme si rien n'était qu' il n'est pas",
#   'start': 240.84,
#   'duration': 2.429},
#  {'text': 'cuite il faut que les riches soient',
#   'start': 242.19,
#   'duration': 3.78},
#  {'text': 'partagées il faut qu en sorte que les',
#   'start': 243.269,
#   'duration': 4.861},
#  {'text': 'commerçants subissent la perte de',
#   'start': 245.97,
#   'duration': 5.46},
#  {'text': 'revenus parce que leurs affaires ne',
#   'start': 248.13,
#   'duration': 5.1},
#  {'text': 'fonctionne pas elle est bloquée et il',
#   'start': 251.43,
#   'duration': 4.5},
#  {'text': 'faut que le propriétaire y subissent la',
#   'start': 253.23,
#   'duration': 5.189},
#  {'text': 'perte du du loyer et chacun ensuite',
#   'start': 255.93,
#   'duration': 4.92},
#  {'text': "s'adresse selon les instruments à",
#   'start': 258.419,
#   'duration': 4.56},
#  {'text': 'disposition au conseil fédéral ou aux',
#   'start': 260.85,
#   'duration': 2.55},
#  {'text': 'comptes', 'start': 262.979, 'duration': 2.581},
#  {'text': 'nous pensons par ailleurs que', 'start': 263.4, 'duration': 4.019},
#  {'text': "au niveau cantonal il faut qu'il y ait",
#   'start': 265.56,
#   'duration': 4.32},
#  {'text': 'un fonds qui viennent en aide à au',
#   'start': 267.419,
#   'duration': 5.521},
#  {'text': 'locataire de logements ou aux locataires',
#   'start': 269.88,
#   'duration': 4.71},
#  {'text': 'commerciaux mais pas ceux qui ont dû',
#   'start': 272.94,
#   'duration': 3.39},
#  {'text': 'fermer à cause des décisions du conseil',
#   'start': 274.59,
#   'duration': 4.14},
#  {'text': 'fédéral pour faire face aux difficultés',
#   'start': 276.33,
#   'duration': 4.77},
#  {'text': 'parce que nombre de locataires auront',
#   'start': 278.73,
#   'duration': 4.8},
#  {'text': 'beaucoup de peine à pouvoir financer',
#   'start': 281.1,
#   'duration': 6.09},
#  {'text': 'leur le loyer à court et moyen terme',
#   'start': 283.53,
#   'duration': 6.3},
#  {'text': "il s'agit là donc de penser à cette",
#   'start': 287.19,
#   'duration': 4.8},
#  {'text': 'catégorie de la population qui est',
#   'start': 289.83,
#   'duration': 3.99},
#  {'text': 'actuellement la plus nombreuse celle des',
#   'start': 291.99,
#   'duration': 4.86},
#  {'text': 'locateurs on va se projeter un tout',
#   'start': 293.82,
#   'duration': 4.38},
#  {'text': 'petit peu pour terminer vers vers',
#   'start': 296.85,
#   'duration': 3.9},
#  {'text': "l'avenir sans être alarmiste on sait que",
#   'start': 298.2,
#   'duration': 5.1},
#  {'text': 'cette crise sanitaire vente ventre et',
#   'start': 300.75,
#   'duration': 4.08},
#  {'text': 'une crise économique que cela va être',
#   'start': 303.3,
#   'duration': 4.05},
#  {'text': 'très compliqué pour certains voire même',
#   'start': 304.83,
#   'duration': 3.899},
#  {'text': 'peut-être perdre leur emploi à cause du',
#   'start': 307.35,
#   'duration': 3.96},
#  {'text': 'que 8,19 vous réfléchissez un mécanisme',
#   'start': 308.729,
#   'duration': 4.5},
#  {'text': 'pour la prêt pour peut-être dont six',
#   'start': 311.31,
#   'duration': 3.66},
#  {'text': 'mois un an contre les conséquences',
#   'start': 313.229,
#   'duration': 3.361},
#  {'text': 'économiques vont vraiment se faire',
#   'start': 314.97,
#   'duration': 4.8},
#  {'text': 'sentir pour écouter je crois que le',
#   'start': 316.59,
#   'duration': 5.49},
#  {'text': "conseil fédéral fait tout pour qu'il n'y",
#   'start': 319.77,
#   'duration': 3.72},
#  {'text': 'ait pas cette crise économique', 'start': 322.08, 'duration': 4.95},
#  {'text': "il y a d'abord le système de la", 'start': 323.49, 'duration': 5.1},
#  {'text': "réduction de l'horaire de travail qui",
#   'start': 327.03,
#   'duration': 3.78},
#  {'text': 'est largement à cliquer et qui permet en',
#   'start': 328.59,
#   'duration': 5.4},
#  {'text': 'fait de maintenir les salariés dans les',
#   'start': 330.81,
#   'duration': 5.58},
#  {'text': 'entreprises on espère que cela puisse',
#   'start': 333.99,
#   'duration': 4.44},
#  {'text': "fonctionner à moyen terme jusqu'au",
#   'start': 336.39,
#   'duration': 4.589},
#  {'text': 'moment où la crise est passé il y a',
#   'start': 338.43,
#   'duration': 4.739},
#  {'text': "énormément d'argent qui est donné sous",
#   'start': 340.979,
#   'duration': 4.981},
#  {'text': 'forme de prêt relais aux entreprises',
#   'start': 343.169,
#   'duration': 4.531},
#  {'text': "pour qu'elles puissent faire face aux",
#   'start': 345.96,
#   'duration': 3.6},
#  {'text': 'obligations haute que les salaires pris',
#   'start': 347.7,
#   'duration': 5.16},
#  {'text': "en charge par l'assurance chômage",
#   'start': 349.56,
#   'duration': 5.51},
#  {'text': 'et puis nous attendons également cette',
#   'start': 352.86,
#   'duration': 5.4},
#  {'text': 'décision du conseil fédéral qui libère',
#   'start': 355.07,
#   'duration': 4.719},
#  {'text': 'du paiement du loyer', 'start': 358.26, 'duration': 5.3},
#  {'text': "les locataires qui n'ont pas de surfaces",
#   'start': 359.789,
#   'duration': 6.271},
#  {'text': 'commerciales exploitables puisque',
#   'start': 363.56,
#   'duration': 5.41},
#  {'text': 'interdit et je pense que cette la crise',
#   'start': 366.06,
#   'duration': 5.82},
#  {'text': 'économique sera cette lamelle là soit',
#   'start': 368.97,
#   'duration': 4.89},
#  {'text': "pas de l'ampleur que l'on pourra",
#   'start': 371.88,
#   'duration': 3.9},
#  {'text': 'connaître dans certains pays voisins',
#   'start': 373.86,
#   'duration': 5.88},
#  {'text': "nous espérons bien que l'ensemble de la",
#   'start': 375.78,
#   'duration': 7.4},
#  {'text': 'population la sortie de crise puissent',
#   'start': 379.74,
#   'duration': 8.489},
#  {'text': 'reprendre avec une relance économique la',
#   'start': 383.18,
#   'duration': 7.06},
#  {'text': 'mesure où il ya des moyens financiers',
#   'start': 388.229,
#   'duration': 4.621},
#  {'text': 'qui sont bien des missions je suis pas',
#   'start': 390.24,
#   'duration': 4.98},
#  {'text': 'économiste donc et surtout pas devant',
#   'start': 392.85,
#   'duration': 5.129},
#  {'text': "veut pas dire qu'il sera plus tard mais",
#   'start': 395.22,
#   'duration': 3.59},
#  {'text': "il faut aujourd'hui", 'start': 397.979, 'duration': 3.111},
#  {'text': 'ces options aux petits commerçants',
#   'start': 398.81,
#   'duration': 4.079},
#  {'text': 'seront ils sont ceux qui souffrent le',
#   'start': 401.09,
#   'duration': 3.93},
#  {'text': "plus aujourd'hui puisque c'est pas la",
#   'start': 402.889,
#   'duration': 4.231},
#  {'text': 'crise des grands prix des grosses bottes',
#   'start': 405.02,
#   'duration': 3.72},
#  {'text': 'lacées grosses multinationales', 'start': 407.12, 'duration': 3.75},
#  {'text': "aujourd'hui mais c'est la crise des",
#   'start': 408.74,
#   'duration': 3.87},
#  {'text': 'petites gens des petits locataires des',
#   'start': 410.87,
#   'duration': 3.12},
#  {'text': 'petits salariés des petits indépendants',
#   'start': 412.61,
#   'duration': 3.96},
#  {'text': "et c'est pour eux il faut s'engager et",
#   'start': 413.99,
#   'duration': 4.26},
#  {'text': 'que le conseil fédéral comme le conseil',
#   'start': 416.57,
#   'duration': 3.75},
#  {'text': "d'état doit le faire merci beaucoup",
#   'start': 418.25,
#   'duration': 4.26},
#  {'text': 'carlo sommaruga président laisse le cas',
#   'start': 420.32,
#   'duration': 4.83},
#  {'text': 'merci à très bientôt en studio sur radio',
#   'start': 422.51,
#   'duration': 5.67},
#  {'text': 'nac excellente journée la firme journée',
#   'start': 425.15,
#   'duration': 5.33},
#  {'text': 'à tous', 'start': 428.18, 'duration': 2.3}]

# %%
video_trans = ""

# %%
for i in range(len(srt)):
    s = srt[i]['text'] + ' '
    video_trans += s

# %% [markdown]
# ## Translate captions

# %%
model_checkpoint = "Helsinki-NLP/opus-mt-fr-en"
translator = pipeline("translation", model=model_checkpoint)

# %%
video_trans_split =  video_trans.split(' ')

# %%
n_words = len(video_trans_split)
batch_size = 200
trans_text = []
n_batches = n_words//batch_size
for i in range(n_batches):
    batch_text = ' '.join(video_trans_split[i*batch_size: (i+1)*batch_size])
    trans_text.append(translator(batch_text)[0]['translation_text'])

# %%
trans_text.append(translator(' '.join(video_trans_split[(n_batches * batch_size):]))[0]['translation_text'])

# %% [markdown]
# ## Create context vector

# %%
context_vector = ' '.join(trans_text)

# %%
with open('topics.pickle', 'rb') as handle:
    topics_to_keyword = pickle.load(handle)

# %%
d = {'video_number': [1], 'context': [context_vector]}
df = pd.DataFrame(data=d)

# %%
classes = [set() for _ in range(len(df))]

for i, context in enumerate(df["context"]):
    for topic in topics_to_keyword:
        for keyword in topics_to_keyword[topic]:
            if keyword in context:
                classes[i].add(topic)

# %%
df['topic'] = classes

# %% [markdown]
# ## Import df questions

# %%
df_questions = pd.read_csv('./csv/carlo_questions_keywords.csv', sep=';', encoding='latin-1')

# %%
#convert to binary
df_questions["question"] = df_questions['question'].str[4:-2]
df_questions.loc[df_questions['smartvote_answers'] >= 3, 'binary_smarvote_answer'] = 0
df_questions.loc[df_questions['smartvote_answers'] <= 2, 'binary_smarvote_answer'] = 1

# %%
topics =  list(topics_to_keyword.keys())

# %%
videos_with_topic = defaultdict(list)

# %%
for i in range(len(df)):
    if df.iloc[i]['topic']:
        for topic in df.iloc[i]['topic']:
            videos_with_topic[topic].append(df.iloc[i]['context'])

# %%
context_videos = {}

# %%
#join context vidoes
for topic in topics:
    context_videos[topic] = ''.join(videos_with_topic[topic])

# %%
qa_model = pipeline("question-answering", model = "srcocotero/bert-large-qa")

# %%
# THIS IS ONLY VALID FOR ONE VIDEO, NEED TO CHANGE CODE for MULTIPLE VIDEOS!!!!!!!

huggingface_answers = []
for i in tqdm(range(len(df_questions))):
    question = df_questions.iloc[i]['Simplified question']
    topic = df_questions.iloc[i]['Topic']
    context = df['context'][0]        
    huggingface_answers.append(qa_model(question = question, context = context))
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 100%|██████████| 60/60 [06:01<00:00,  6.02s/it]

# %%
df_questions["huggingface_answers"] = huggingface_answers

# %%
df_questions.to_csv("./csv/questions/video_answers.csv")

# %%
df_questions_videos=pd.read_csv("./csv/questions/videos_cami_label.csv", delimiter = ';')

# %%
df_questions_videos
# Out:
#     Column1                                           question  \
# 0         0  Êtes-vous favorable à une hausse de l'âge de l...
# 1         1   L'État devrait-il renforcer son soutien finan...
# 2         2   Une initiative demande l'instauration d'un co...
# 3         3   Les rentes de la caisse de pension doivent-el...
# 4         4   Soutenez-vous les efforts au niveau des canto...
# 5         5   La Confédération devrait-elle encourager dava...
# 6         6   Les personnes assurées devraient-elles contri...
# 7         7   Approuveriez-vous le principe du consentement...
# 8         8  Une vaccination obligatoire des enfants basée ...
# 9         9   Une initiative demande que les subsides aux a...
# 10       10   Une initiative souhaite donner à la Confédéra...
# 11       11   LÉtat devrait-il davantage sengager pour un...
# 12       12   Pensez-vous qu'il soit juste que les écoles o...
# 13       13   La Confédération devrait-elle accroître son s...
# 14       14   Le concept de l'école intégrative prévoit que...
# 15       15   Seriez-vous favorable à ce que le droit de vo...
# 16       16   La limitation de l'immigration a-t-elle pour ...
# 17       17   Les personnes sans-papiers devraient-elles po...
# 18       18   Êtes-vous en faveur d'un durcissement supplém...
# 19       19   Les conditions de naturalisation devraient-el...
# 20       20   La Confédération devrait-elle soutenir davant...
# 21       21   La consommation de cannabis devrait-elle être...
# 22       22   Les couples de même sexe devraient-ils avoir ...
# 23       23  La réglementation de la procréation médicaleme...
# 24       24   Êtes-vous en faveur d'un contrôle plus strict...
# 25       25   Seriez-vous favorable à ce qu'un médecin soit...
# 26       26  Selon vous la baisse des impôts au niveau fédé...
# 27       27   Êtes-vous en faveur d'une nouvelle réduction ...
# 28       28   Les couples mariés devraient-ils être imposés...
# 29       29   Êtes-vous en faveur d'une restriction de la c...
# 30       30   Les ménages privés devraient-ils pouvoir choi...
# 31       31   Êtes-vous favorable à l'introduction d'un sal...
# 32       32   Les entreprises suisses devraient-elles être ...
# 33       33   Seriez-vous favorable à une libéralisation co...
# 34       34   Faut-il renforcer la protection contre le lic...
# 35       35  La Confédération devrait-elle davantage souten...
# 36       36   L'expansion du réseau mobile selon la norme 5...
# 37       37   Les plateformes de services en ligne (p. ex. ...
# 38       38   Une initiative demande que la Suisse cesse d'...
# 39       39  Actuellement une taxe CO2 est prélevée sur les...
# 40       40   La Confédération devrait-elle soutenir davant...
# 41       41   Les tronçons autoroutiers à forte fréquentati...
# 42       42   Êtes-vous favorable à l'introduction de péage...
# 43       43  Êtes-vous favorable à un assouplissement des m...
# 44       44   Le moratoire actuel sur les plantes et les an...
# 45       45  Les paiements directs devraient-ils être accor...
# 46       46   Faut-il étendre les mesures de protection de ...
# 47       47  Êtes-vous en faveur de réglementations plus st...
# 48       48   Le financement des partis ainsi que celui des...
# 49       49   L'introduction du vote électronique lors des ...
# 50       50   Êtes-vous en faveur de l'abaissement de l'âge...
# 51       51   La Suisse devrait-elle mettre fin à l'accord ...
# 52       52   Faut-il renoncer au durcissement des conditio...
# 53       53   Faut-il interdire l'exportation de matériel d...
# 54       54   Êtes-vous favorable à l'acquisition de nouvea...
# 55       55  Selon vous les moyens légaux permettant de rec...
# 56       56   La Suisse doit-elle entamer des négociations ...
# 57       57   La Suisse devrait-elle conclure un accord de ...
# 58       58   Une initiative demande que les règles de resp...
# 59       59   Êtes-vous en faveur de la candidature de la S...
#
#     smartvote_answers  binary_smarvote_answer  \
# 0                   4                       0
# 1                   1                       1
# 2                   1                       1
# 3                   4                       0
# 4                   4                       0
# 5                   1                       1
# 6                   4                       0
# 7                   1                       1
# 8                   1                       1
# 9                   1                       1
# 10                  4                       0
# 11                  1                       1
# 12                  4                       0
# 13                  1                       1
# 14                  2                       1
# 15                  1                       1
# 16                  4                       0
# 17                  1                       1
# 18                  4                       0
# 19                  4                       0
# 20                  1                       1
# 21                  1                       1
# 22                  1                       1
# 23                  1                       1
# 24                  1                       1
# 25                  1                       1
# 26                  4                       0
# 27                  3                       0
# 28                  1                       1
# 29                  1                       1
# 30                  4                       0
# 31                  1                       1
# 32                  2                       1
# 33                  4                       0
# 34                  1                       1
# 35                  1                       1
# 36                  3                       0
# 37                  1                       1
# 38                  1                       1
# 39                  1                       1
# 40                  1                       1
# 41                  4                       0
# 42                  4                       0
# 43                  4                       0
# 44                  1                       1
# 45                  1                       1
# 46                  1                       1
# 47                  1                       1
# 48                  1                       1
# 49                  1                       1
# 50                  3                       0
# 51                  4                       0
# 52                  1                       1
# 53                  1                       1
# 54                  4                       0
# 55                  2                       1
# 56                  4                       0
# 57                  1                       1
# 58                  1                       1
# 59                  1                       1
#
#                                   huggingface_answers  cami_answers  \
# 0   {'score': 0.13347554206848145, 'start': 5024, ...             2
# 1   {'score': 0.05516103655099869, 'start': 5960, ...             2
# 2   {'score': 0.01262223906815052, 'start': 5024, ...             2
# 3   {'score': 0.07364076375961304, 'start': 5960, ...             2
# 4   {'score': 0.00976233184337616, 'start': 2641, ...             2
# 5   {'score': 0.021911006420850754, 'start': 5075,...             2
# 6   {'score': 0.01624414511024952, 'start': 1901, ...             0
# 7   {'score': 0.007623670622706413, 'start': 4507,...             2
# 8   {'score': 0.029254939407110214, 'start': 5925,...             1
# 9   {'score': 0.012008112855255604, 'start': 3443,...             2
# 10  {'score': 0.06880854070186615, 'start': 4636, ...             2
# 11  {'score': 0.014760797843337059, 'start': 5960,...             2
# 12  {'score': 0.01539386436343193, 'start': 4636, ...             2
# 13  {'score': 0.02402248978614807, 'start': 3708, ...             2
# 14  {'score': 0.01069261971861124, 'start': 2940, ...             2
# 15  {'score': 0.04903941974043846, 'start': 5910, ...             2
# 16  {'score': 0.016271773725748062, 'start': 5960,...             2
# 17  {'score': 0.014008332043886185, 'start': 2527,...             2
# 18  {'score': 0.008623538538813591, 'start': 5960,...             2
# 19  {'score': 0.05264553800225258, 'start': 5443, ...             2
# 20  {'score': 0.03912564739584923, 'start': 5925, ...             1
# 21  {'score': 0.015655456110835075, 'start': 5910,...             2
# 22  {'score': 0.017044536769390106, 'start': 4507,...             2
# 23  {'score': 0.043277159333229065, 'start': 2641,...             2
# 24  {'score': 0.008645319379866123, 'start': 5960,...             2
# 25  {'score': 0.023327430710196495, 'start': 5925,...             1
# 26  {'score': 0.12912403047084808, 'start': 4636, ...             2
# 27  {'score': 0.043166402727365494, 'start': 5925,...             1
# 28  {'score': 0.05855897441506386, 'start': 4507, ...             2
# 29  {'score': 0.0057405875995755196, 'start': 1624...             2
# 30  {'score': 0.03824697062373161, 'start': 5910, ...             2
# 31  {'score': 0.01140714529901743, 'start': 6024, ...             2
# 32  {'score': 0.02849500998854637, 'start': 5910, ...             2
# 33  {'score': 0.18914814293384552, 'start': 4636, ...             2
# 34  {'score': 0.023670950904488564, 'start': 5024,...             2
# 35  {'score': 0.011894299648702145, 'start': 5960,...             2
# 36  {'score': 0.020896226167678833, 'start': 5910,...             2
# 37  {'score': 0.024190953001379967, 'start': 5960,...             2
# 38  {'score': 0.03134067729115486, 'start': 2641, ...             2
# 39  {'score': 0.04872377961874008, 'start': 5164, ...             2
# 40  {'score': 0.02085059881210327, 'start': 5925, ...             1
# 41  {'score': 0.01000105869024992, 'start': 5960, ...             2
# 42  {'score': 0.02789224311709404, 'start': 5024, ...             2
# 43  {'score': 0.01080845482647419, 'start': 2641, ...             2
# 44  {'score': 0.07542579621076584, 'start': 2133, ...             2
# 45  {'score': 0.006934586446732283, 'start': 1800,...             2
# 46  {'score': 0.04358052462339401, 'start': 2133, ...             2
# 47  {'score': 0.03788143768906593, 'start': 5024, ...             2
# 48  {'score': 0.021637948229908943, 'start': 5925,...             1
# 49  {'score': 0.014784147031605244, 'start': 5960,...             2
# 50  {'score': 0.0819140151143074, 'start': 5925, '...             2
# 51  {'score': 0.015932539477944374, 'start': 5910,...             2
# 52  {'score': 0.018983125686645508, 'start': 1901,...             0
# 53  {'score': 0.010064641013741493, 'start': 5910,...             2
# 54  {'score': 0.010624540969729424, 'start': 2940,...             2
# 55  {'score': 0.029912061989307404, 'start': 5960,...             2
# 56  {'score': 0.025063123553991318, 'start': 1482,...             2
# 57  {'score': 0.02310831844806671, 'start': 885, '...             2
# 58  {'score': 0.007552596740424633, 'start': 5960,...             2
# 59  {'score': 0.04241489991545677, 'start': 5960, ...             2
#
#                  Topic                                      Keywords  \
# 0               family                             pension; AHV; AVS
# 1               family                   benefit; childcare; nursery
# 2               family                             paternity; leave
# 3               family                      pension; life expectancy
# 4               family                   benefits; social assistance
# 5               family  social housing; construction; public housing
# 6               health        health cost; health care cost; premium
# 7               health                               organ; donation
# 8               health                          vaccine; vaccination
# 9               health                 insurance; premium; subsidies
# 10              health                  cost brake; health care cost
# 11           education   education opportunities; subsidies; courses
# 12           education                       religion; sex education
# 13           education               education support; reconversion
# 14           education                learning; school; disabilities
# 15         immigration            vote; resident; communal elections
# 16         immigration                    bilateral; EU; immigration
# 17         immigration             undocumented; residence; migrants
# 18         immigration                                        asylum
# 19         immigration                                naturalisation
# 20         immigration                                   integration
# 21             society                                      cannabis
# 22             society                               homosexual; gay
# 23             society                                 reproducation
# 24             society                               equal; salaries
# 25             society                           doctor; euthanasia
# 26            finances                                         taxes
# 27            finances                       financial equalisation
# 28            finances                  individual taxation; married
# 29            finances                              company taxation
# 30             economy                                   electricity
# 31             economy                                          wage
# 32             economy          FDI; investement controls; takeovers
# 33             economy                          opening hours; shops
# 34             economy                            dismissal; workers
# 35             economy                  public services; post office
# 36      digitalisation                                            5G
# 37      digitalisation                          Uber; Airbnb; online
# 38              energy                            fossil; 2050; fuel
# 39              energy                              C02; natural gas
# 40              energy                             renewable; energy
# 41              energy                               motorway; lanes
# 42              energy                                  road pricing
# 43             ecology                  predators; lynx; wolf; bears
# 44             ecology                 plants; genetically modified
# 45             ecology                 ecological; farms; pesticides
# 46             ecology                                  biodiversity
# 47             ecology                  animal protection; livestock
# 48            politics               campaign funding; transparency;
# 49            politics                               e-voting; votes
# 50            politics                                voting age; 16
# 51            security                      border control; schengen
# 52            security                                 civil service
# 53            security                         war material; weapons
# 54            security                          aircraft; swiss army
# 55            security                                          dann
# 56  external_relations                               EU negotiations
# 57  external_relations                                   trade; USA
# 58  external_relations                     human rights; environment
# 59  external_relations                              security council
#
#                                   Simplified question
# 0   ''Are you in favour of raising the retirement ...
# 1            ''Should the state support childcare? ''
# 2         ''Are you in favour of a paternity leave?''
# 3         ''Should the finance state pension funds?''
# 4                   ''Are you in favor of benefits?''
# 5             ''Are you in favor of public housing?''
# 6           ''Should the health insurance cost more''
# 7                         ''Is organ donation good?''
# 8                 ''Should vaccines be compulsory? ''
# 9   ''Should health be proportional to your income?''
# 10           ''Should health care costs be reduced?''
# 11  ''Should we care about education opportunities?''
# 12                ''Should schools exempts classes?''
# 13            ''Should education have more funding?''
# 14              ''Do you support inclusive schools?''
# 15                         'Should foreigners vote?''
# 16           ''Should we limit immigration from EU?''
# 17  ''Should undocumented migrants receive a statu...
# 18                    ''Are you in favor of asylum?''
# 19  ''Should the conditions for naturaliation be i...
# 20         "Should we support foreigner integration?"
# 21                        "Should cannabis be legal?"
# 22         "Do we believe in homosexuality equality?"
# 23  ' Should the regulation of assisted reproducti...
# 24  "Do you support stricter control of equal pay ...
# 25                      "Should euthanasia be legal?"
# 26                           "Should we lower taxes?"
# 27               "Should cantons support each other?"
# 28           "Do you believe in individual taxation?"
# 29  "Are you in favor of restricting competition b...
# 30  "Should we be a able to choose their electrici...
# 31              "Are you in favor of a minimum wage?"
# 32  "Should we protect Swiss companies from foreig...
# 33        "Should stores choose their opening hours?"
# 34  "Should the protection against dismissal of ol...
# 35  "Should we support public services in rural ar...
# 36                 "Should we expand our 5G network?"
# 37             "Should we regulate online platforms?"
# 38         "Do you want to stop using fossil fuels?''
# 39                            "Should fuel be taxed?"
# 40            "Should we support renewable energies?"
# 41  "Should high-traffic highway sections be exten...
# 42  "Do you support the introduction of road prici...
# 43  "'Are you in favor of relaxing the current pro...
# 44  'Should the current moratorium on genetically ...
# 45  'Should direct payments only be granted to far...
# 46  "Should biodiversity protection measures be ex...
# 47  "Do you support stricter animal protection reg...
# 48     " Should campaign financing be transparent? ''
# 49                         "Do you support e-voting?"
# 50                   "Should voting at 16 be allowed"
# 51                  "Should Switzerland end Shengen?"
# 52  'Should the Federal Council's proposed tighten...
# 53                   "Should we export war material?"
# 54  "Are you in favor of acquiring new fighter air...
# 55                  "Should we do more DNA analysis?"
# 56     "Should Switzerland enter the European Union?"
# 57  "Should Switzerlad have a free trade agreement...
# 58  "Should Swiss companies have human rights and ...
# 59  "Should Switzerland have a seat in the UN Secu...

# %% [markdown]
# ## Evaluation

# %%
sklearn.metrics.confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answers"])
# Out:
# array([[ 1,  1, 19],
#        [ 1,  5, 33],
#        [ 0,  0,  0]])

# %%
from sklearn.metrics import confusion_matrix

labels = ['0', '1', '2']
cm = confusion_matrix(df_questions_videos["binary_smarvote_answer"], df_questions_videos["cami_answers"])
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix for Tweets using All tweets')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 1  1 19]
#  [ 1  5 33]
#  [ 0  0  0]]
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# not very optimistic, transcription is not great
# --> and then we translate
# add more videos, create context vectors
